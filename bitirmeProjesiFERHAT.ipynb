# %%
import pandas as pd
import matplotlib.pyplot as plt

df_B0 = pd.read_excel('NiMnSn-spodi-data (1).xlsx', sheet_name= 'B=0')
df_B2 = pd.read_excel('NiMnSn-spodi-data (1).xlsx', sheet_name= 'B=2 T')
df_B3 = pd.read_excel('NiMnSn-spodi-data (1).xlsx', sheet_name= 'B=5 T')
# Out:
# Bad key "text.kerning_factor" on line 4 in
# c:\Users\user\anaconda3\conda\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
df_B0.rename(columns={"2 Theta":"2Theta"}, inplace=True)
df_B2.rename(columns={"2 Theta":"2Theta"}, inplace=True)
df_B3.rename(columns={"2 Theta":"2Theta"}, inplace=True)

# %%
#df to np array
B0_2Theta = df_B0['2Theta'].values
B0_5K = df_B0['5 K'].values
B0_94K = df_B0['94 K'].values
B0_117K = df_B0['117 K'].values
B0_137K = df_B0['137K'].values
B0_158K = df_B0['158 K'].values
B0_180K = df_B0['180 K'].values
B0_203K = df_B0['203 K'].values
B0_227K = df_B0['227 K'].values
B0_253K = df_B0['253 K'].values
B0_290K = df_B0['290 K'].values

B2_2Theta = df_B2['2Theta'].values
B2_5K = df_B2['5 K'].values
B2_76K = df_B2['76 K'].values
B2_98K = df_B2['98 K'].values
B2_118K = df_B2['118 K'].values
B2_138K = df_B2['138 K'].values
B2_157K = df_B2['157 K'].values
B2_177K = df_B2['177 K'].values
B2_197K = df_B2['197 K'].values
B2_218K = df_B2['218 K'].values
B2_240K = df_B2['240 K'].values
B2_290K = df_B2['290 K'].values

B3_2Theta = df_B3['2Theta'].values
B3_5K = df_B3['5 K'].values
B3_76K = df_B3['76 K'].values
B3_98K = df_B3['98 K'].values
B3_118K = df_B3['118 K'].values
B3_138K = df_B3['138 K'].values
B3_157K = df_B3['157 K'].values
B3_177K = df_B3['177 K'].values
B3_197K = df_B3['197 K'].values
B3_218K = df_B3['218 K'].values
B3_240K = df_B3['240 K'].values
B3_290K = df_B3['290 K'].values

# %%
from scipy.signal import find_peaks
peaks, _ = find_peaks(B0_5K, threshold=50)
plt.plot(peaks, B0_5K[peaks], "x")
peaks2, _ = find_peaks(B0_94K, threshold=50)
plt.plot(peaks2, B0_94K[peaks2], "x")
peaks3, _ = find_peaks(B0_117K, threshold=50)
plt.plot(peaks3, B0_137K[peaks3], "x")
peaks4, _ = find_peaks(B0_137K, threshold=50)
plt.plot(peaks4, B0_137K[peaks4], "x")
peaks5, _ = find_peaks(B0_158K, threshold=50)
plt.plot(peaks5, B0_158K[peaks5], "x")
peaks6, _ = find_peaks(B0_180K, threshold=50)
plt.plot(peaks6, B0_180K[peaks6], "x")
peaks7, _ = find_peaks(B0_203K, threshold=50)
plt.plot(peaks7, B0_203K[peaks7], "x")
peaks8, _ = find_peaks(B0_227K, threshold=50)
plt.plot(peaks8, B0_227K[peaks8], "x")
peaks9, _ = find_peaks(B0_253K, threshold=50)
plt.plot(peaks9, B0_253K[peaks9], "x")

# %% [markdown]
# ### Peaks and Widths for **B=0** and **T=5K**

# %%
df_B0
plt.plot(df_B0['2Theta'], df_B0['5 K'])
peaks, _ = find_peaks(B0_5K, threshold=55, prominence=2000)

for i in range(9):
    peaks[i] = df_B0['2Theta'][peaks[i]]
    
    
# plt.plot(peaks, B0_5K[peaks], "x")


B0_5K[peaks]
# Out:
# array([1118, 1026, 1014, 1049, 1019, 1027,  915,  868,  833], dtype=int64)

# %%
B0_2Theta[peaks]
# Out:
# array([ 26.25,  29.5 ,  32.  ,  42.4 ,  43.95,  54.  ,  70.35,  78.4 ,
#        100.9 ])

# %%
B0_5K[peaks]
# Out:
# array([ 4360, 13284,  6351,  3529,  9157,  5448,  3370,  3604,  3267],
#       dtype=int64)

# %%
#Peaks for B=0 and T=5K

from scipy.signal import chirp, find_peaks, peak_widths
import matplotlib.pyplot as plt

plt.plot(B0_2Theta,B0_5K)

peaks, _ = find_peaks(B0_5K, threshold=55, prominence=2000)
plt.plot(B0_2Theta[peaks], B0_5K[peaks], "x")


plt.xlabel('2ϴ / Degrees')
plt.ylabel('Intensity')
plt.title("Intensities for B=0T and T=5K")
plt.savefig('B0_5K_peaks_reportSON.png')
plt.yticks([])

plt.xlim(20,120)
plt.axhline(y = 2000, color = 'r', linestyle = 'dashed')

plt.annotate('Peak 1', xy=(26.25, 4360), xytext=(26.25, 4360))
plt.annotate('Peak 2', xy=(29.5, 13284), xytext=(29.5, 13284))
plt.annotate('Peak 3', xy=(32, 6351), xytext=(32, 6351))
plt.annotate('Peak 4', xy=(42.4, 3529), xytext=(42.4, 3529))
plt.annotate('Peak 5', xy=(43.95, 9157), xytext=(43.95, 9157))
plt.annotate('Peak 6', xy=(54, 5448), xytext=(54, 5448))
plt.annotate('Peak 7', xy=(70.35, 3370), xytext=(66.35, 3370))
plt.annotate('Peak 8', xy=(78.4, 3604), xytext=(79, 3604))
plt.annotate('Peak 9', xy=(100.9, 3267), xytext=(100.9, 3267))
# Out:
# Text(100.9,3267,'Peak 9')

# %% [markdown]
# ### Areas Under Peaks for **B=0** and **T=5K**

# %%
import numpy as np


B0_5K_areas = []


area_peak1_B0_5K = np.trapz(B0_5K[437:451], dx=1)
area_peak2_B0_5K = np.trapz(B0_5K[504:516], dx=1)
area_peak3_B0_5K = np.trapz(B0_5K[553:565], dx=1)
area_peak4_B0_5K = np.trapz(B0_5K[763:773], dx=1)
area_peak5_B0_5K = np.trapz(B0_5K[793:805], dx=1)
area_peak6_B0_5K = np.trapz(B0_5K[983:1006], dx=1)
area_peak7_B0_5K = np.trapz(B0_5K[1303:1336], dx=1)
area_peak8_B0_5K = np.trapz(B0_5K[1467:1506], dx=1)
area_peak9_B0_5K = np.trapz(B0_5K[1908:1954], dx=1)

#append above to B0_5K_areas
B0_5K_areas.append(area_peak1_B0_5K)
B0_5K_areas.append(area_peak2_B0_5K)
B0_5K_areas.append(area_peak3_B0_5K)
B0_5K_areas.append(area_peak4_B0_5K)
B0_5K_areas.append(area_peak5_B0_5K)
B0_5K_areas.append(area_peak6_B0_5K)
B0_5K_areas.append(area_peak7_B0_5K)
B0_5K_areas.append(area_peak8_B0_5K)
B0_5K_areas.append(area_peak9_B0_5K)

B0_5K_areas
# Out:
# [41290.0,
#  95207.0,
#  47165.5,
#  24138.0,
#  65190.0,
#  70797.5,
#  71137.0,
#  67630.5,
#  77720.5]

# %% [markdown]
# ### Peaks and Widths for **B=0** and **T=94K** *[In comparison with T=5K]*

# %%
##Area under peaks for B=0 and T= 94 K - 203 K
plt.plot(df_B0['94 K'])
plt.plot(df_B0['203 K'])




plt.xlabel('2ϴ Index Values')
plt.ylabel('Intensity')
plt.title("Intensities for B=0 - T=94K and T=203K")



#add legend to the plot
plt.legend(['94 K', '203 K'])
plt.yticks([])
plt.savefig('B0_5K_94K_peaks_reportSON.png')

# %% [markdown]
# ### Areas Under Peaks for **B=0** and **T=94K**

# %%
B0_94K_areas = []

area_peak1_B0_94K = np.trapz(B0_94K[437:451], dx=1)
area_peak2_B0_94K = np.trapz(B0_94K[505:517], dx=1)
area_peak3_B0_94K = np.trapz(B0_94K[551:563], dx=1)
area_peak4_B0_94K = np.trapz(B0_94K[763:773], dx=1)
area_peak5_B0_94K = np.trapz(B0_94K[791:803], dx=1)
area_peak6_B0_94K = np.trapz(B0_94K[982:1004], dx=1)
area_peak7_B0_94K = np.trapz(B0_94K[1320:1334], dx=1)
area_peak8_B0_94K = np.trapz(B0_94K[1466:1503], dx=1)
area_peak9_B0_94K = np.trapz(B0_94K[1920:1946], dx=1)

#append above to B0_94K_areas
B0_94K_areas.append(area_peak1_B0_94K)
B0_94K_areas.append(area_peak2_B0_94K)
B0_94K_areas.append(area_peak3_B0_94K)
B0_94K_areas.append(area_peak4_B0_94K)
B0_94K_areas.append(area_peak5_B0_94K)
B0_94K_areas.append(area_peak6_B0_94K)
B0_94K_areas.append(area_peak7_B0_94K)
B0_94K_areas.append(area_peak8_B0_94K)
B0_94K_areas.append(area_peak9_B0_94K)





B0_94K_areas
# Out:
# [4662.5, 10363.5, 5221.0, 2826.5, 6704.5, 7149.5, 3813.0, 7119.0, 6038.5]

# %% [markdown]
# ### Peaks and Widths for **B=0** and **T=117K**

# %%
plt.plot(df_B0['5 K'])
plt.plot(df_B0['117 K'])
peaks, _ = find_peaks(B0_5K, threshold=55, prominence=2000)
peaks3, _ = find_peaks(B0_117K, prominence=170)
plt.plot(peaks, B0_5K[peaks], "x", color='black')
plt.plot(peaks3, B0_117K[peaks3], "x", color='red')

results_half = peak_widths(B0_5K, peaks, rel_height=0.85)
plt.hlines(*results_half[1:], color="C2")


results_half = peak_widths(B0_117K, peaks3, rel_height=0.85)
plt.hlines(*results_half[1:], color="C2")

# %% [markdown]
# ### Areas Under Peaks for **B=0** and **T=117K**

# %%
B0_117K_areas = []

area_peak1_B0_117K = np.trapz(B0_117K[437:451], dx=1)
area_peak2_B0_117K = np.trapz(B0_117K[505:517], dx=1)
area_peak3_B0_117K = np.trapz(B0_117K[549:561], dx=1)
area_peak4_B0_117K = np.trapz(B0_117K[754:773], dx=1)
area_peak5_B0_117K = np.trapz(B0_117K[789:803], dx=1)
area_peak6_B0_117K = np.trapz(B0_117K[982:1004], dx=1)
area_peak7_B0_117K = np.trapz(B0_117K[1321:1331], dx=1)
area_peak8_B0_117K = np.trapz(B0_117K[1469:1503], dx=1)
area_peak9_B0_117K = np.trapz(B0_117K[1918:1943], dx=1)

#append above to B0_117K_areas
B0_117K_areas.append(area_peak1_B0_117K)
B0_117K_areas.append(area_peak2_B0_117K)
B0_117K_areas.append(area_peak3_B0_117K)
B0_117K_areas.append(area_peak4_B0_117K)
B0_117K_areas.append(area_peak5_B0_117K)
B0_117K_areas.append(area_peak6_B0_117K)
B0_117K_areas.append(area_peak7_B0_117K)
B0_117K_areas.append(area_peak8_B0_117K)
B0_117K_areas.append(area_peak9_B0_117K)

B0_117K_areas
# Out:
# [4547.0, 8153.0, 4509.5, 4416.0, 6969.5, 7318.0, 2743.5, 7426.0, 5344.5]

# %% [markdown]
# ### Peaks and Widths for **B=0** and **T=137K** *(Burada bir peak ikiye ayrılıyor)*

# %%
#Area under peaks for B=0 and T= 137 K
peaks4, _ = find_peaks(B0_137K, prominence=170)


results_half = peak_widths(B0_137K, peaks4, rel_height=0.85)


results_half = peak_widths(B0_5K, peaks, rel_height=0.85)
plt.hlines(*results_half[1:], color="C2")

plt.plot(df_B0['5 K'])
plt.plot(peaks, B0_5K[peaks], "x", color='black')
plt.plot(df_B0['137K'])

results_half = peak_widths(B0_137K, peaks4, rel_height=0.85)
plt.plot(peaks4, B0_137K[peaks4], "x", color='red')
plt.hlines(*results_half[1:], color="C2")

# %% [markdown]
# ### Areas Under Peaks for **B=0** and **T=137K** (*Peak 9'dan sonra garip bir peak daha var*)

# %%
B0_137K_areas = []

area_peak1_B0_137K = np.trapz(B0_137K[437:450], dx=1)
area_peak2_B0_137K = np.trapz(B0_137K[505:530], dx=1)
area_peak3_B0_137K = np.trapz(B0_137K[548:561], dx=1)
area_peak4_B0_137K = np.trapz(B0_137K[765:774], dx=1)
area_peak5_B0_137K = np.trapz(B0_137K[790:801], dx=1)
area_peak6_B0_137K = np.trapz(B0_137K[983:1001], dx=1)
area_peak7_B0_137K = np.trapz(B0_137K[1323:1343], dx=1)
area_peak8_B0_137K = np.trapz(B0_137K[1481:1504], dx=1)
area_peak9_B0_137K = np.trapz(B0_137K[1918:1941], dx=1)

#PEAK 9'DAN SONRA GARİP BİR PEAK DAHA VAR

#append above to B0_137K_areas
B0_137K_areas.append(area_peak1_B0_137K)
B0_137K_areas.append(area_peak2_B0_137K)
B0_137K_areas.append(area_peak3_B0_137K)
B0_137K_areas.append(area_peak4_B0_137K)
B0_137K_areas.append(area_peak5_B0_137K)
B0_137K_areas.append(area_peak6_B0_137K)
B0_137K_areas.append(area_peak7_B0_137K)
B0_137K_areas.append(area_peak8_B0_137K)
B0_137K_areas.append(area_peak9_B0_137K)

B0_137K_areas
# Out:
# [4463.0, 15052.5, 4178.5, 1724.0, 5094.5, 6675.0, 7450.0, 6135.0, 4352.0]

# %% [markdown]
# ### Peaks and Widths for **B=0** and **T=158K**

# %%
plt.plot(df_B0['5 K'])
plt.plot(df_B0['158 K'])
peaks, _ = find_peaks(B0_5K, threshold=55, prominence=2000)
peaks5, _ = find_peaks(B0_158K, prominence=170)
plt.plot(peaks, B0_5K[peaks], "x", color='black')
plt.plot(peaks5, B0_158K[peaks5], "x", color='red')

results_half = peak_widths(B0_5K, peaks, rel_height=0.85)
plt.hlines(*results_half[1:], color="C2")


results_half = peak_widths(B0_158K, peaks5, rel_height=0.85)
plt.hlines(*results_half[1:], color="C2")

# %% [markdown]
# ### Areas Under Peaks for **B=0** and **T=158K** *(İkinci,dördüncü, dokuzuncu peaklerde anomali var)*

# %%
B0_158K_areas = []

area_peak1_B0_158K = np.trapz(B0_158K[437:448], dx=1)
area_peak2_B0_158K = np.trapz(B0_158K[507:516], dx=1)
area_peak3_B0_158K = np.trapz(B0_158K[546:562], dx=1)
area_peak4_B0_158K = np.trapz(B0_158K[755:774], dx=1)
area_peak5_B0_158K = np.trapz(B0_158K[790:801], dx=1)
area_peak6_B0_158K = np.trapz(B0_158K[985:997], dx=1)
area_peak7_B0_158K = np.trapz(B0_158K[1305:1330], dx=1)
area_peak8_B0_158K = np.trapz(B0_158K[1488:1503], dx=1)
area_peak9_B0_158K = np.trapz(B0_158K[1909:1953], dx=1)


#append above to B0_158K_areas
B0_158K_areas.append(area_peak1_B0_158K)
B0_158K_areas.append(area_peak2_B0_158K)
B0_158K_areas.append(area_peak3_B0_158K)
B0_158K_areas.append(area_peak4_B0_158K)
B0_158K_areas.append(area_peak5_B0_158K)
B0_158K_areas.append(area_peak6_B0_158K)
B0_158K_areas.append(area_peak7_B0_158K)
B0_158K_areas.append(area_peak8_B0_158K)
B0_158K_areas.append(area_peak9_B0_158K)

B0_158K_areas
# Out:
# [4406.5, 2111.5, 2222.0, 2442.5, 2077.0, 6813.5, 3216.0, 6389.0, 6453.0]

# %% [markdown]
# ### Peaks and Widths for **B=0** and **T=180K**

# %%
plt.plot(df_B0['5 K'])
plt.plot(df_B0['180 K'])
peaks, _ = find_peaks(B0_5K, threshold=55, prominence=2000)
peaks6, _ = find_peaks(B0_180K, prominence=170)
plt.plot(peaks, B0_5K[peaks], "x", color='black')
plt.plot(peaks6, B0_180K[peaks6], "x", color='red')

results_half = peak_widths(B0_5K, peaks, rel_height=0.85)
plt.hlines(*results_half[1:], color="C2")


results_half = peak_widths(B0_180K, peaks6, rel_height=0.85)
plt.hlines(*results_half[1:], color="C2")

# %% [markdown]
# ### Areas Under Peaks for **B=0** and **T=180K** *(İkinci,dördüncü, dokuzuncu peaklerde anomali var)*

# %%
B0_180K_areas = []

area_peak1_B0_180K = np.trapz(B0_180K[437:447], dx=1)
area_peak2_B0_180K = np.trapz(B0_180K[519:529], dx=1)
area_peak3_B0_180K = np.trapz(B0_180K[550:560], dx=1)
area_peak4_B0_180K = np.trapz(B0_180K[755:774], dx=1)
area_peak5_B0_180K = np.trapz(B0_180K[778:788], dx=1)
area_peak6_B0_180K = np.trapz(B0_180K[985:995], dx=1)
area_peak7_B0_180K = np.trapz(B0_180K[1333:1343], dx=1)
area_peak8_B0_180K = np.trapz(B0_180K[1492:1503], dx=1)
area_peak9_B0_180K = np.trapz(B0_180K[1955:1966], dx=1)


#append above to B0_180K_areas
B0_180K_areas.append(area_peak1_B0_180K)
B0_180K_areas.append(area_peak2_B0_180K)
B0_180K_areas.append(area_peak3_B0_180K)
B0_180K_areas.append(area_peak4_B0_180K)
B0_180K_areas.append(area_peak5_B0_180K)
B0_180K_areas.append(area_peak6_B0_180K)
B0_180K_areas.append(area_peak7_B0_180K)
B0_180K_areas.append(area_peak8_B0_180K)
B0_180K_areas.append(area_peak9_B0_180K)

B0_180K_areas
# Out:
# [4579.0, 15883.0, 1092.0, 1717.0, 13041.5, 6941.0, 11582.0, 8478.5, 9860.5]

# %% [markdown]
# ### Peaks and Widths for **B=0** and **T=203K**

# %%
plt.plot(df_B0['5 K'])
plt.plot(df_B0['203 K'])
peaks, _ = find_peaks(B0_5K, threshold=55, prominence=2000)
peaks7, _ = find_peaks(B0_203K, prominence=170)
plt.plot(peaks, B0_5K[peaks], "x", color='black')
plt.plot(peaks7, B0_203K[peaks7], "x", color='red')

results_half = peak_widths(B0_5K, peaks, rel_height=0.85)
plt.hlines(*results_half[1:], color="C2")


results_half = peak_widths(B0_203K, peaks7, rel_height=0.85)
plt.hlines(*results_half[1:], color="C2")

# %% [markdown]
# ### Areas Under Peaks for **B=0** and **T=203K**

# %%
B0_203K_areas = []

area_peak1_B0_203K = np.trapz(B0_203K[437:447], dx=1)
area_peak2_B0_203K = np.trapz(B0_203K[519:529], dx=1)
area_peak3_B0_203K = np.trapz(B0_203K[548:550], dx=1)
area_peak4_B0_203K = np.trapz(B0_203K[756:762], dx=1)
area_peak5_B0_203K = np.trapz(B0_203K[778:788], dx=1)
area_peak6_B0_203K = np.trapz(B0_203K[983:994], dx=1)
area_peak7_B0_203K = np.trapz(B0_203K[1333:1343], dx=1)
area_peak8_B0_203K = np.trapz(B0_203K[1492:1503], dx=1)
area_peak9_B0_203K = np.trapz(B0_203K[1954:1966], dx=1)


#append above to B0_203K_areas
B0_203K_areas.append(area_peak1_B0_203K)
B0_203K_areas.append(area_peak2_B0_203K)
B0_203K_areas.append(area_peak3_B0_203K)
B0_203K_areas.append(area_peak4_B0_203K)
B0_203K_areas.append(area_peak5_B0_203K)
B0_203K_areas.append(area_peak6_B0_203K)
B0_203K_areas.append(area_peak7_B0_203K)
B0_203K_areas.append(area_peak8_B0_203K)
B0_203K_areas.append(area_peak9_B0_203K)

B0_203K_areas
# Out:
# [5063.5, 15542.5, 97.0, 483.0, 13266.5, 6431.5, 11704.0, 8807.5, 10609.5]

# %% [markdown]
# ### Peaks and Widths for **B=0** and **T=227K**

# %%
plt.plot(df_B0['5 K'])
plt.plot(df_B0['227 K'])
peaks, _ = find_peaks(B0_5K, threshold=55, prominence=2000)
peaks8, _ = find_peaks(B0_227K, prominence=170)
plt.plot(peaks, B0_5K[peaks], "x", color='black')
plt.plot(peaks8, B0_227K[peaks8], "x", color='red')

results_half = peak_widths(B0_5K, peaks, rel_height=0.85)
plt.hlines(*results_half[1:], color="C2")


results_half = peak_widths(B0_227K, peaks8, rel_height=0.85)
plt.hlines(*results_half[1:], color="C2")

# %% [markdown]
# ### Areas Under Peaks for **B=0** and **T=227K**

# %%
B0_227K_areas = []

area_peak1_B0_227K = np.trapz(B0_227K[437:447], dx=1)
area_peak2_B0_227K = np.trapz(B0_227K[519:529], dx=1)
area_peak3_B0_227K = np.trapz(B0_227K[553:565], dx=1)
area_peak4_B0_227K = np.trapz(B0_227K[763:773], dx=1)
area_peak5_B0_227K = np.trapz(B0_227K[778:787], dx=1)
area_peak6_B0_227K = np.trapz(B0_227K[984:994], dx=1)
area_peak7_B0_227K = np.trapz(B0_227K[1331:1343], dx=1)
area_peak8_B0_227K = np.trapz(B0_227K[1491:1502], dx=1)
area_peak9_B0_227K = np.trapz(B0_227K[1953:1965], dx=1)


#append above to B0_227K_areas
B0_227K_areas.append(area_peak1_B0_227K)
B0_227K_areas.append(area_peak2_B0_227K)
B0_227K_areas.append(area_peak3_B0_227K)
B0_227K_areas.append(area_peak4_B0_227K)
B0_227K_areas.append(area_peak5_B0_227K)
B0_227K_areas.append(area_peak6_B0_227K)
B0_227K_areas.append(area_peak7_B0_227K)
B0_227K_areas.append(area_peak8_B0_227K)
B0_227K_areas.append(area_peak9_B0_227K)

B0_227K_areas
# Out:
# [4483.0, 13374.0, 997.5, 867.5, 12761.0, 6246.0, 12767.0, 8468.0, 8730.0]

# %% [markdown]
# ### Peaks and Widths for **B=0** and **T=253K**

# %%
plt.plot(df_B0['5 K'])
plt.plot(df_B0['253 K'])
peaks, _ = find_peaks(B0_5K, threshold=55, prominence=2000)
peaks9, _ = find_peaks(B0_253K, prominence=170)
plt.plot(peaks, B0_5K[peaks], "x", color='black')
plt.plot(peaks9, B0_253K[peaks9], "x", color='red')

results_half = peak_widths(B0_5K, peaks, rel_height=0.85)
plt.hlines(*results_half[1:], color="C2")


results_half = peak_widths(B0_253K, peaks9, rel_height=0.85)
plt.hlines(*results_half[1:], color="C2")

# %% [markdown]
# ### Areas Under Peaks for **B=0** and **T=253K**

# %%
B0_253K_areas = []

area_peak1_B0_253K = np.trapz(B0_253K[436:447], dx=1)
area_peak2_B0_253K = np.trapz(B0_253K[507:516], dx=1)
area_peak3_B0_253K = np.trapz(B0_253K[554:566], dx=1)
area_peak4_B0_253K = np.trapz(B0_253K[763:773], dx=1)
area_peak5_B0_253K = np.trapz(B0_253K[777:787], dx=1)
area_peak6_B0_253K = np.trapz(B0_253K[984:994], dx=1)
area_peak7_B0_253K = np.trapz(B0_253K[1332:1342], dx=1)
area_peak8_B0_253K = np.trapz(B0_253K[1490:1501], dx=1)
area_peak9_B0_253K = np.trapz(B0_253K[1952:1965], dx=1)


#append above to B0_253K_areas
B0_253K_areas.append(area_peak1_B0_253K)
B0_253K_areas.append(area_peak2_B0_253K)
B0_253K_areas.append(area_peak3_B0_253K)
B0_253K_areas.append(area_peak4_B0_253K)
B0_253K_areas.append(area_peak5_B0_253K)
B0_253K_areas.append(area_peak6_B0_253K)
B0_253K_areas.append(area_peak7_B0_253K)
B0_253K_areas.append(area_peak8_B0_253K)
B0_253K_areas.append(area_peak9_B0_253K)

B0_253K_areas
# Out:
# [4291.0, 921.5, 1014.0, 864.0, 11997.5, 6123.0, 10559.0, 10203.5, 10020.0]

# %% [markdown]
# ### Peaks and Widths for **B=0** and **T=290K**

# %%
plt.plot(df_B0['5 K'])
plt.plot(df_B0['290 K'])
peaks, _ = find_peaks(B0_5K, threshold=55, prominence=2000)
peaks10, _ = find_peaks(B0_290K, prominence=170)
plt.plot(peaks, B0_5K[peaks], "x", color='black')
plt.plot(peaks10, B0_290K[peaks10], "x", color='red')

results_half = peak_widths(B0_5K, peaks, rel_height=0.85)
plt.hlines(*results_half[1:], color="C2")


results_half = peak_widths(B0_290K, peaks10, rel_height=0.85)
plt.hlines(*results_half[1:], color="C2")

# %% [markdown]
# ### Areas Under Peaks for **B=0** and **T=290K**

# %%
B0_290K_areas = []

area_peak1_B0_290K = np.trapz(B0_290K[436:447], dx=1)
area_peak2_B0_290K = np.trapz(B0_290K[518:529], dx=1)
area_peak3_B0_290K = np.trapz(B0_290K[554:565], dx=1)
area_peak4_B0_290K = np.trapz(B0_290K[764:773], dx=1)
area_peak5_B0_290K = np.trapz(B0_290K[777:787], dx=1)
area_peak6_B0_290K = np.trapz(B0_290K[983:993], dx=1)
area_peak7_B0_290K = np.trapz(B0_290K[1331:1342], dx=1)
area_peak8_B0_290K = np.trapz(B0_290K[1489:1501], dx=1)
area_peak9_B0_290K = np.trapz(B0_290K[1951:1964], dx=1)


#append above to B0_290K_areas
B0_290K_areas.append(area_peak1_B0_290K)
B0_290K_areas.append(area_peak2_B0_290K)
B0_290K_areas.append(area_peak3_B0_290K)
B0_290K_areas.append(area_peak4_B0_290K)
B0_290K_areas.append(area_peak5_B0_290K)
B0_290K_areas.append(area_peak6_B0_290K)
B0_290K_areas.append(area_peak7_B0_290K)
B0_290K_areas.append(area_peak8_B0_290K)
B0_290K_areas.append(area_peak9_B0_290K)

B0_290K_areas
# Out:
# [4171.5, 16058.0, 902.0, 822.5, 13310.0, 6205.5, 11312.0, 10704.5, 8684.5]

# %% [markdown]
# ### Peaks and Widths for **B=2T** and **T=5K**

# %%
plt.plot(df_B2['5 K'])

peaks1_b2, _ = find_peaks(B2_5K, threshold=15, prominence=680)
plt.plot(peaks1_b2, B2_5K[peaks1_b2], "x")

results_half = peak_widths(B2_5K, peaks1_b2, rel_height=0.85)

plt.hlines(*results_half[1:], color="C2")

# %%
plt.plot(df_B0['5 K'], color='black')

peaks1_b0, _ = find_peaks(B0_5K, threshold=15, prominence=680)

plt.plot(peaks, B0_5K[peaks], "x")

plt.plot(df_B3['5 K'], color='red')

peaks1_b3, _ = find_peaks(B3_5K, threshold=15, prominence=680)

# %% [markdown]
# ### Areas Under Peaks for **B=2T** and **T=5K**

# %%
B2_5K_areas = []

area_peak1_B2_5K = np.trapz(B2_5K[437:447], dx=1)
area_peak2_B2_5K = np.trapz(B2_5K[507:516], dx=1)
area_peak3_B2_5K = np.trapz(B2_5K[546:562], dx=1)
area_peak4_B2_5K = np.trapz(B2_5K[755:774], dx=1)
area_peak5_B2_5K = np.trapz(B2_5K[790:801], dx=1)
area_peak6_B2_5K = np.trapz(B2_5K[985:995], dx=1)
area_peak7_B2_5K = np.trapz(B2_5K[1305:1330], dx=1)
area_peak8_B2_5K = np.trapz(B2_5K[1492:1503], dx=1)
area_peak9_B2_5K = np.trapz(B2_5K[1909:1953], dx=1)


#append above to B2_5K_areas
B2_5K_areas.append(area_peak1_B2_5K)
B2_5K_areas.append(area_peak2_B2_5K)
B2_5K_areas.append(area_peak3_B2_5K)
B2_5K_areas.append(area_peak4_B2_5K)
B2_5K_areas.append(area_peak5_B2_5K)
B2_5K_areas.append(area_peak6_B2_5K)
B2_5K_areas.append(area_peak7_B2_5K)
B2_5K_areas.append(area_peak8_B2_5K)
B2_5K_areas.append(area_peak9_B2_5K)

B2_5K_areas
# Out:
# [8732.0, 19591.5, 9112.0, 13228.5, 12934.0, 7778.5, 14700.0, 4557.5, 20751.0]

# %% [markdown]
# ### Peaks and Widths for **B=2T** and **T=76K** *(ilk kısımlarda garip peakler var)*

# %%
plt.plot(df_B2['5 K'])

peaks1_b2, _ = find_peaks(B2_5K, threshold=15, prominence=680)
plt.plot(peaks1_b2, B2_5K[peaks1_b2], "x")

results_half = peak_widths(B2_5K, peaks1_b2, rel_height=0.85)

plt.hlines(*results_half[1:], color="C2")
plt.plot(df_B2['76 K'])

peaks2_b2, _ = find_peaks(B2_76K, threshold=15, prominence=680)
plt.plot(peaks2_b2, B2_76K[peaks2_b2], "x")

results_half = peak_widths(B2_76K, peaks2_b2, rel_height=0.85)

plt.hlines(*results_half[1:], color="C2")

# %% [markdown]
# ### Areas Under Peaks for **B=2T** and **T=76K**

# %%
B2_76K_areas = []

area_peak1_B2_76K = np.trapz(B2_76K[437:447], dx=1)
area_peak2_B2_76K = np.trapz(B2_76K[507:516], dx=1)
area_peak3_B2_76K = np.trapz(B2_76K[546:562], dx=1)
area_peak4_B2_76K = np.trapz(B2_76K[755:774], dx=1)
area_peak5_B2_76K = np.trapz(B2_76K[790:801], dx=1)
area_peak6_B2_76K = np.trapz(B2_76K[985:995], dx=1)
area_peak7_B2_76K = np.trapz(B2_76K[1305:1330], dx=1)
area_peak8_B2_76K = np.trapz(B2_76K[1492:1503], dx=1)
area_peak9_B2_76K = np.trapz(B2_76K[1909:1953], dx=1)


#append above to B2_76K_areas
B2_76K_areas.append(area_peak1_B2_76K)
B2_76K_areas.append(area_peak2_B2_76K)
B2_76K_areas.append(area_peak3_B2_76K)
B2_76K_areas.append(area_peak4_B2_76K)
B2_76K_areas.append(area_peak5_B2_76K)
B2_76K_areas.append(area_peak6_B2_76K)
B2_76K_areas.append(area_peak7_B2_76K)
B2_76K_areas.append(area_peak8_B2_76K)
B2_76K_areas.append(area_peak9_B2_76K)

B2_76K_areas
# Out:
# [723.5, 696.5, 1115.0, 1289.0, 782.5, 695.5, 5533.5, 778.0, 4532.0]

# %% [markdown]
# ### Peaks and Widths for **B=2T** and **T=98K** *(ilk kısımlarda daha az garip peakler var)*

# %%
plt.plot(df_B2['5 K'])

peaks1_b2, _ = find_peaks(B2_5K, threshold=15, prominence=680)
plt.plot(peaks1_b2, B2_5K[peaks1_b2], "x")

plt.plot(df_B2['98 K'])

peaks3_b2, _ = find_peaks(B2_98K, threshold=15, prominence=680)
plt.plot(peaks3_b2, B2_98K[peaks3_b2], "x")

results_half = peak_widths(B2_98K, peaks3_b2, rel_height=0.85)

plt.hlines(*results_half[1:], color="C2")

# %% [markdown]
# ### Areas Under Peaks for **B=2T** and **T=98K**

# %%
B2_98K_areas = []

area_peak1_B2_98K = np.trapz(B2_98K[437:447], dx=1)
area_peak2_B2_98K = np.trapz(B2_98K[507:516], dx=1)
area_peak3_B2_98K = np.trapz(B2_98K[546:562], dx=1)
area_peak4_B2_98K = np.trapz(B2_98K[755:774], dx=1)
area_peak5_B2_98K = np.trapz(B2_98K[790:801], dx=1)
area_peak6_B2_98K = np.trapz(B2_98K[985:995], dx=1)
area_peak7_B2_98K = np.trapz(B2_98K[1305:1330], dx=1)
area_peak8_B2_98K = np.trapz(B2_98K[1492:1503], dx=1)
area_peak9_B2_98K = np.trapz(B2_98K[1909:1953], dx=1)


#append above to B2_98K_areas
B2_98K_areas.append(area_peak1_B2_98K)
B2_98K_areas.append(area_peak2_B2_98K)
B2_98K_areas.append(area_peak3_B2_98K)
B2_98K_areas.append(area_peak4_B2_98K)
B2_98K_areas.append(area_peak5_B2_98K)
B2_98K_areas.append(area_peak6_B2_98K)
B2_98K_areas.append(area_peak7_B2_98K)
B2_98K_areas.append(area_peak8_B2_98K)
B2_98K_areas.append(area_peak9_B2_98K)

B2_98K_areas
# Out:
# [761.0, 716.0, 1818.0, 2508.0, 684.0, 691.5, 4815.0, 743.5, 5429.5]

# %% [markdown]
# ### Peaks and Widths for **B=2T** and **T=118K**

# %%
plt.plot(df_B2['5 K'])

peaks1_b2, _ = find_peaks(B2_5K, threshold=15, prominence=680)
plt.plot(peaks1_b2, B2_5K[peaks1_b2], "x")

results_half = peak_widths(B2_5K, peaks1_b2, rel_height=0.85)
plt.plot(df_B2['118 K'])

peaks4_b2, _ = find_peaks(B2_118K, threshold=15, prominence=680)
plt.plot(peaks4_b2, B2_118K[peaks4_b2], "x")

results_half = peak_widths(B2_118K, peaks4_b2, rel_height=0.85)

plt.hlines(*results_half[1:], color="C2")

# %% [markdown]
# ### Areas Under Peaks for **B=2T** and **T=118K**

# %%
B2_118K_areas = []

area_peak1_B2_118K = np.trapz(B2_118K[437:447], dx=1)
area_peak2_B2_118K = np.trapz(B2_118K[507:516], dx=1)
area_peak3_B2_118K = np.trapz(B2_118K[546:562], dx=1)
area_peak4_B2_118K = np.trapz(B2_118K[755:774], dx=1)
area_peak5_B2_118K = np.trapz(B2_118K[790:801], dx=1)
area_peak6_B2_118K = np.trapz(B2_118K[985:995], dx=1)
area_peak7_B2_118K = np.trapz(B2_118K[1305:1330], dx=1)
area_peak8_B2_118K = np.trapz(B2_118K[1492:1503], dx=1)
area_peak9_B2_118K = np.trapz(B2_118K[1909:1953], dx=1)


#append above to B2_118K_areas
B2_118K_areas.append(area_peak1_B2_118K)
B2_118K_areas.append(area_peak2_B2_118K)
B2_118K_areas.append(area_peak3_B2_118K)
B2_118K_areas.append(area_peak4_B2_118K)
B2_118K_areas.append(area_peak5_B2_118K)
B2_118K_areas.append(area_peak6_B2_118K)
B2_118K_areas.append(area_peak7_B2_118K)
B2_118K_areas.append(area_peak8_B2_118K)
B2_118K_areas.append(area_peak9_B2_118K)

B2_118K_areas
# Out:
# [756.5, 592.0, 1279.5, 1130.5, 955.5, 641.0, 2248.5, 877.0, 6149.0]

# %% [markdown]
# ### Peaks and Widths for **B=2T** and **T=138K**

# %%
plt.plot(df_B2['5 K'])

peaks1_b2, _ = find_peaks(B2_5K, threshold=15, prominence=680)
plt.plot(peaks1_b2, B2_5K[peaks1_b2], "x")

results_half = peak_widths(B2_5K, peaks1_b2, rel_height=0.85)
plt.plot(df_B2['138 K'])

peaks5_b2, _ = find_peaks(B2_138K, threshold=15, prominence=680)
plt.plot(peaks5_b2, B2_138K[peaks5_b2], "x")

results_half = peak_widths(B2_138K, peaks5_b2, rel_height=0.85)

plt.hlines(*results_half[1:], color="C2")

# %% [markdown]
# ### Areas Under Peaks for **B=2T** and **T=138K**

# %%
B2_138K_areas = []

area_peak1_B2_138K = np.trapz(B2_138K[437:447], dx=1)
area_peak2_B2_138K = np.trapz(B2_138K[507:516], dx=1)
area_peak3_B2_138K = np.trapz(B2_138K[546:562], dx=1)
area_peak4_B2_138K = np.trapz(B2_138K[755:774], dx=1)
area_peak5_B2_138K = np.trapz(B2_138K[790:801], dx=1)
area_peak6_B2_138K = np.trapz(B2_138K[985:995], dx=1)
area_peak7_B2_138K = np.trapz(B2_138K[1305:1330], dx=1)
area_peak8_B2_138K = np.trapz(B2_138K[1492:1503], dx=1)
area_peak9_B2_138K = np.trapz(B2_138K[1909:1953], dx=1)


#append above to B2_138K_areas
B2_138K_areas.append(area_peak1_B2_138K)
B2_138K_areas.append(area_peak2_B2_138K)
B2_138K_areas.append(area_peak3_B2_138K)
B2_138K_areas.append(area_peak4_B2_138K)
B2_138K_areas.append(area_peak5_B2_138K)
B2_138K_areas.append(area_peak6_B2_138K)
B2_138K_areas.append(area_peak7_B2_138K)
B2_138K_areas.append(area_peak8_B2_138K)
B2_138K_areas.append(area_peak9_B2_138K)

B2_138K_areas
# Out:
# [2633.0, 739.5, 1470.0, 1189.5, 923.5, 583.5, 2134.0, 863.5, 5029.5]

# %% [markdown]
# ### Peaks and Widths for **B=2T** and **T=157K**

# %%
plt.plot(df_B2['5 K'])

peaks1_b2, _ = find_peaks(B2_5K, threshold=15, prominence=680)
plt.plot(peaks1_b2, B2_5K[peaks1_b2], "x")

results_half = peak_widths(B2_5K, peaks1_b2, rel_height=0.85)
plt.plot(df_B2['157 K'])

peaks6_b2, _ = find_peaks(B2_157K, threshold=15, prominence=680)
plt.plot(peaks5_b2, B2_157K[peaks6_b2], "x")

results_half = peak_widths(B2_157K, peaks6_b2, rel_height=0.85)

plt.hlines(*results_half[1:], color="C2")

# %% [markdown]
# ### Areas Under Peaks for **B=2T** and **T=157K**

# %%
B2_157K_areas = []

area_peak1_B2_157K = np.trapz(B2_157K[437:447], dx=1)
area_peak2_B2_157K = np.trapz(B2_157K[507:516], dx=1)
area_peak3_B2_157K = np.trapz(B2_157K[546:562], dx=1)
area_peak4_B2_157K = np.trapz(B2_157K[755:774], dx=1)
area_peak5_B2_157K = np.trapz(B2_157K[790:801], dx=1)
area_peak6_B2_157K = np.trapz(B2_157K[985:995], dx=1)
area_peak7_B2_157K = np.trapz(B2_157K[1305:1330], dx=1)
area_peak8_B2_157K = np.trapz(B2_157K[1492:1503], dx=1)
area_peak9_B2_157K = np.trapz(B2_157K[1909:1953], dx=1)


#append above to B2_157K_areas
B2_157K_areas.append(area_peak1_B2_157K)
B2_157K_areas.append(area_peak2_B2_157K)
B2_157K_areas.append(area_peak3_B2_157K)
B2_157K_areas.append(area_peak4_B2_157K)
B2_157K_areas.append(area_peak5_B2_157K)
B2_157K_areas.append(area_peak6_B2_157K)
B2_157K_areas.append(area_peak7_B2_157K)
B2_157K_areas.append(area_peak8_B2_157K)
B2_157K_areas.append(area_peak9_B2_157K)

B2_157K_areas
# Out:
# [840.0, 681.0, 1229.0, 1349.0, 620.5, 672.5, 2815.0, 765.0, 4523.5]

# %% [markdown]
# ### Peaks and Widths for **B=2T** and **T=177K** *(peakler farklı yerlerde ama amplitude'lar çok çok yüksek)*

# %%
plt.plot(df_B2['5 K'])

peaks1_b2, _ = find_peaks(B2_5K, threshold=15, prominence=680)
plt.plot(peaks1_b2, B2_5K[peaks1_b2], "x")

results_half = peak_widths(B2_5K, peaks1_b2, rel_height=0.85)
plt.plot(df_B2['177 K'])

peaks7_b2, _ = find_peaks(B2_177K, threshold=15, prominence=680)
plt.plot(peaks7_b2, B2_177K[peaks7_b2], "x")

results_half = peak_widths(B2_157K, peaks7_b2, rel_height=0.85)

plt.hlines(*results_half[1:], color="C2")
# Out:
# <ipython-input-39-c00f098897d4>:12: PeakPropertyWarning: some peaks have a prominence of 0
#   results_half = peak_widths(B2_157K, peaks7_b2, rel_height=0.85)
# <ipython-input-39-c00f098897d4>:12: PeakPropertyWarning: some peaks have a width of 0
#   results_half = peak_widths(B2_157K, peaks7_b2, rel_height=0.85)

# %% [markdown]
# ### Areas Under Peaks for **B=2T** and **T=177K**

# %%
B2_177K_areas = []

area_peak1_B2_177K = np.trapz(B2_177K[437:447], dx=1)
area_peak2_B2_177K = np.trapz(B2_177K[507:516], dx=1)
area_peak3_B2_177K = np.trapz(B2_177K[546:562], dx=1)
area_peak4_B2_177K = np.trapz(B2_177K[755:774], dx=1)
area_peak5_B2_177K = np.trapz(B2_177K[790:801], dx=1)
area_peak6_B2_177K = np.trapz(B2_177K[985:995], dx=1)
area_peak7_B2_177K = np.trapz(B2_177K[1305:1330], dx=1)
area_peak8_B2_177K = np.trapz(B2_177K[1492:1503], dx=1)
area_peak9_B2_177K = np.trapz(B2_177K[1909:1953], dx=1)


#append above to B2_177K_areas
B2_177K_areas.append(area_peak1_B2_177K)
B2_177K_areas.append(area_peak2_B2_177K)
B2_177K_areas.append(area_peak3_B2_177K)
B2_177K_areas.append(area_peak4_B2_177K)
B2_177K_areas.append(area_peak5_B2_177K)
B2_177K_areas.append(area_peak6_B2_177K)
B2_177K_areas.append(area_peak7_B2_177K)
B2_177K_areas.append(area_peak8_B2_177K)
B2_177K_areas.append(area_peak9_B2_177K)

B2_177K_areas
# Out:
# [7606.0, 643.0, 1287.5, 1254.0, 711.5, 674.5, 5102.0, 928.5, 5708.5]

# %% [markdown]
# ### Peaks and Widths for **B=2T** and **T=197K** *(boynuz kulağı geçti ama farklı yerlerde)*

# %%
plt.plot(df_B2['5 K'])

peaks1_b2, _ = find_peaks(B2_5K, threshold=15, prominence=680)
plt.plot(peaks1_b2, B2_5K[peaks1_b2], "x")

results_half = peak_widths(B2_5K, peaks1_b2, rel_height=0.85)
plt.plot(df_B2['197 K'])

peaks8_b2, _ = find_peaks(B2_197K, threshold=15, prominence=680)
plt.plot(peaks8_b2, B2_197K[peaks8_b2], "x")

results_half = peak_widths(B2_197K, peaks8_b2, rel_height=0.85)

plt.hlines(*results_half[1:], color="C2")

# %% [markdown]
# ### Areas Under Peaks for **B=2T** and **T=197K**

# %%
B2_197K_areas = []

area_peak1_B2_197K = np.trapz(B2_197K[437:447], dx=1)
area_peak2_B2_197K = np.trapz(B2_197K[507:516], dx=1)
area_peak3_B2_197K = np.trapz(B2_197K[546:562], dx=1)
area_peak4_B2_197K = np.trapz(B2_197K[755:774], dx=1)
area_peak5_B2_197K = np.trapz(B2_197K[790:801], dx=1)
area_peak6_B2_197K = np.trapz(B2_197K[985:995], dx=1)
area_peak7_B2_197K = np.trapz(B2_197K[1305:1330], dx=1)
area_peak8_B2_197K = np.trapz(B2_197K[1492:1503], dx=1)
area_peak9_B2_197K = np.trapz(B2_197K[1909:1953], dx=1)


#append above to B2_197K_areas
B2_197K_areas.append(area_peak1_B2_197K)
B2_197K_areas.append(area_peak2_B2_197K)
B2_197K_areas.append(area_peak3_B2_197K)
B2_197K_areas.append(area_peak4_B2_197K)
B2_197K_areas.append(area_peak5_B2_197K)
B2_197K_areas.append(area_peak6_B2_197K)
B2_197K_areas.append(area_peak7_B2_197K)
B2_197K_areas.append(area_peak8_B2_197K)
B2_197K_areas.append(area_peak9_B2_197K)

B2_197K_areas
# Out:
# [862.0, 628.5, 1255.0, 1345.0, 722.0, 628.5, 2080.0, 767.0, 4567.0]

# %% [markdown]
# ### Peaks and Widths for **B=2T** and **T=218K**

# %%
plt.plot(df_B2['5 K'])

peaks1_b2, _ = find_peaks(B2_5K, threshold=15, prominence=680)
plt.plot(peaks1_b2, B2_5K[peaks1_b2], "x")

results_half = peak_widths(B2_5K, peaks1_b2, rel_height=0.85)
plt.plot(df_B2['218 K'])

peaks9_b2, _ = find_peaks(B2_218K, threshold=15, prominence=680)
plt.plot(peaks9_b2, B2_218K[peaks9_b2], "x")

results_half = peak_widths(B2_218K, peaks9_b2, rel_height=0.85)

plt.hlines(*results_half[1:], color="C2")

# %% [markdown]
# ### Areas Under Peaks for **B=2T** and **T=218K**

# %%
B2_218K_areas = []

area_peak1_B2_218K = np.trapz(B2_218K[437:447], dx=1)
area_peak2_B2_218K = np.trapz(B2_218K[507:516], dx=1)
area_peak3_B2_218K = np.trapz(B2_218K[546:562], dx=1)
area_peak4_B2_218K = np.trapz(B2_218K[755:774], dx=1)
area_peak5_B2_218K = np.trapz(B2_218K[790:801], dx=1)
area_peak6_B2_218K = np.trapz(B2_218K[985:995], dx=1)
area_peak7_B2_218K = np.trapz(B2_218K[1305:1330], dx=1)
area_peak8_B2_218K = np.trapz(B2_218K[1492:1503], dx=1)
area_peak9_B2_218K = np.trapz(B2_218K[1909:1953], dx=1)


#append above to B2_218K_areas
B2_218K_areas.append(area_peak1_B2_218K)
B2_218K_areas.append(area_peak2_B2_218K)
B2_218K_areas.append(area_peak3_B2_218K)
B2_218K_areas.append(area_peak4_B2_218K)
B2_218K_areas.append(area_peak5_B2_218K)
B2_218K_areas.append(area_peak6_B2_218K)
B2_218K_areas.append(area_peak7_B2_218K)
B2_218K_areas.append(area_peak8_B2_218K)
B2_218K_areas.append(area_peak9_B2_218K)

B2_218K_areas
# Out:
# [728.5, 654.0, 1187.5, 1640.5, 800.0, 669.5, 2135.5, 833.0, 15394.5]

# %% [markdown]
# ### Peaks and Widths for **B=2T** and **T=240K**

# %%
plt.plot(df_B2['5 K'])

peaks1_b2, _ = find_peaks(B2_5K, threshold=15, prominence=680)
plt.plot(peaks1_b2, B2_5K[peaks1_b2], "x")

results_half = peak_widths(B2_5K, peaks1_b2, rel_height=0.85)
plt.plot(df_B2['240 K'])

peaks10_b2, _ = find_peaks(B2_240K, threshold=15, prominence=680)
plt.plot(peaks10_b2, B2_240K[peaks10_b2], "x")

results_half = peak_widths(B2_240K, peaks10_b2, rel_height=0.85)

plt.hlines(*results_half[1:], color="C2")

# %% [markdown]
# ### Areas Under Peaks for **B=2T** and **T=240K**

# %%
B2_240K_areas = []

area_peak1_B2_240K = np.trapz(B2_240K[437:447], dx=1)
area_peak2_B2_240K = np.trapz(B2_240K[507:516], dx=1)
area_peak3_B2_240K = np.trapz(B2_240K[546:562], dx=1)
area_peak4_B2_240K = np.trapz(B2_240K[755:774], dx=1)
area_peak5_B2_240K = np.trapz(B2_240K[790:801], dx=1)
area_peak6_B2_240K = np.trapz(B2_240K[985:995], dx=1)
area_peak7_B2_240K = np.trapz(B2_240K[1305:1330], dx=1)
area_peak8_B2_240K = np.trapz(B2_240K[1492:1503], dx=1)
area_peak9_B2_240K = np.trapz(B2_240K[1909:1953], dx=1)


#append above to B2_240K_areas
B2_240K_areas.append(area_peak1_B2_240K)
B2_240K_areas.append(area_peak2_B2_240K)
B2_240K_areas.append(area_peak3_B2_240K)
B2_240K_areas.append(area_peak4_B2_240K)
B2_240K_areas.append(area_peak5_B2_240K)
B2_240K_areas.append(area_peak6_B2_240K)
B2_240K_areas.append(area_peak7_B2_240K)
B2_240K_areas.append(area_peak8_B2_240K)
B2_240K_areas.append(area_peak9_B2_240K)

B2_240K_areas
# Out:
# [739.5, 1999.5, 1219.5, 18818.0, 755.0, 703.5, 13126.0, 922.5, 14743.0]

# %% [markdown]
# ### Peaks and Widths for **B=2T** and **T=290K**

# %%
plt.plot(df_B2['5 K'])

peaks1_b2, _ = find_peaks(B2_5K, threshold=15, prominence=680)
plt.plot(peaks1_b2, B2_5K[peaks1_b2], "x")

results_half = peak_widths(B2_5K, peaks1_b2, rel_height=0.85)
plt.plot(df_B2['290 K'])

peaks11_b2, _ = find_peaks(B2_290K, threshold=15, prominence=680)
plt.plot(peaks11_b2, B2_290K[peaks11_b2], "x")

results_half = peak_widths(B2_290K, peaks11_b2, rel_height=0.85)

plt.hlines(*results_half[1:], color="C2")

# %% [markdown]
# ### Areas Under Peaks for **B=2T** and **T=290K**

# %%
B2_290K_areas = []

area_peak1_B2_290K = np.trapz(B2_290K[437:447], dx=1)
area_peak2_B2_290K = np.trapz(B2_290K[507:516], dx=1)
area_peak3_B2_290K = np.trapz(B2_290K[546:562], dx=1)
area_peak4_B2_290K = np.trapz(B2_290K[755:774], dx=1)
area_peak5_B2_290K = np.trapz(B2_290K[790:801], dx=1)
area_peak6_B2_290K = np.trapz(B2_290K[985:995], dx=1)
area_peak7_B2_290K = np.trapz(B2_290K[1305:1330], dx=1)
area_peak8_B2_290K = np.trapz(B2_290K[1492:1503], dx=1)
area_peak9_B2_290K = np.trapz(B2_290K[1909:1953], dx=1)


#append above to B2_290K_areas
B2_290K_areas.append(area_peak1_B2_290K)
B2_290K_areas.append(area_peak2_B2_290K)
B2_290K_areas.append(area_peak3_B2_290K)
B2_290K_areas.append(area_peak4_B2_290K)
B2_290K_areas.append(area_peak5_B2_290K)
B2_290K_areas.append(area_peak6_B2_290K)
B2_290K_areas.append(area_peak7_B2_290K)
B2_290K_areas.append(area_peak8_B2_290K)
B2_290K_areas.append(area_peak9_B2_290K)

B2_290K_areas
# Out:
# [3943.5, 716.5, 1192.0, 1686.5, 970.0, 5810.5, 2264.0, 7211.0, 5784.0]

# %% [markdown]
# ### Peaks and Widths for **B=5T** and **T=5K**

# %%
plt.plot(df_B3['5 K'])

peaks1_b3, _ = find_peaks(B3_5K, threshold=15, prominence=680)
plt.plot(peaks1_b3, B3_5K[peaks1_b3], "x")

results_half = peak_widths(B3_5K, peaks1_b3, rel_height=0.85)


plt.plot(df_B0['5 K'], color="red")

peaks, _ = find_peaks(B0_5K, threshold=55, prominence=2000)

plt.plot(peaks, B0_5K[peaks], "x", color='black')


results_half = peak_widths(B0_5K, peaks, rel_height=0.85)
plt.hlines(*results_half[1:], color="C2")

# %% [markdown]
# ### Areas Under Peaks for **B=5T** and **T=5K**

# %%
B3_5K_areas = []


area_peak1_B3_5K = np.trapz(B3_5K[437:451], dx=1)
area_peak2_B3_5K = np.trapz(B3_5K[504:516], dx=1)
area_peak3_B3_5K = np.trapz(B3_5K[553:565], dx=1)
area_peak4_B3_5K = np.trapz(B3_5K[763:773], dx=1)
area_peak5_B3_5K = np.trapz(B3_5K[793:805], dx=1)
area_peak6_B3_5K = np.trapz(B3_5K[983:1006], dx=1)
area_peak7_B3_5K = np.trapz(B3_5K[1303:1336], dx=1)
area_peak8_B3_5K = np.trapz(B3_5K[1467:1506], dx=1)
area_peak9_B3_5K = np.trapz(B3_5K[1908:1954], dx=1)

#append above to B3_5K_areas
B3_5K_areas.append(area_peak1_B3_5K)
B3_5K_areas.append(area_peak2_B3_5K)
B3_5K_areas.append(area_peak3_B3_5K)
B3_5K_areas.append(area_peak4_B3_5K)
B3_5K_areas.append(area_peak5_B3_5K)
B3_5K_areas.append(area_peak6_B3_5K)
B3_5K_areas.append(area_peak7_B3_5K)
B3_5K_areas.append(area_peak8_B3_5K)
B3_5K_areas.append(area_peak9_B3_5K)

print(sum(B0_5K_areas),sum(B3_5K_areas))
# Out:
# 560276.0 469901.5

# %% [markdown]
# ### Peaks and Widths for **B=5T** and **T=76K** *(neredeyse tamamı yok olmuş, ilk kısımda alakasız peak var)*

# %%
plt.plot(df_B0['5 K'], color="red")

peaks, _ = find_peaks(B0_5K, threshold=55, prominence=2000)

plt.plot(peaks, B0_5K[peaks], "x", color='black')


results_half = peak_widths(B0_5K, peaks, rel_height=0.85)
plt.hlines(*results_half[1:], color="C2")


plt.plot(df_B3['76 K'])
peaks2_b3, _ = find_peaks(B3_76K, threshold=15, prominence=680)
plt.plot(peaks2_b3, B3_76K[peaks2_b3], "x")

# %% [markdown]
# ### Areas Under Peaks for **B=5T** and **T=76K**

# %%
B3_76K_areas = []

area_peak1_B3_76K = np.trapz(B3_76K[260:270], dx=1)
area_peak2_B3_76K = np.trapz(B3_76K[325:335], dx=1)
area_peak3_B3_76K = np.trapz(B3_76K[375:385], dx=1)
area_peak4_B3_76K = np.trapz(B3_76K[585:592], dx=1)
area_peak5_B3_76K = np.trapz(B3_76K[615:624], dx=1)
area_peak6_B3_76K = np.trapz(B3_76K[815:823], dx=1)
area_peak7_B3_76K = np.trapz(B3_76K[1140:1153], dx=1)
area_peak8_B3_76K = np.trapz(B3_76K[1302:1316], dx=1)
area_peak9_B3_76K = np.trapz(B3_76K[1749:1764], dx=1)


#append above to B3_76K_areas
B3_76K_areas.append(area_peak1_B3_76K)
B3_76K_areas.append(area_peak2_B3_76K)
B3_76K_areas.append(area_peak3_B3_76K)
B3_76K_areas.append(area_peak4_B3_76K)
B3_76K_areas.append(area_peak5_B3_76K)
B3_76K_areas.append(area_peak6_B3_76K)
B3_76K_areas.append(area_peak7_B3_76K)
B3_76K_areas.append(area_peak8_B3_76K)
B3_76K_areas.append(area_peak9_B3_76K)

B3_76K_areas
# Out:
# [3784.5, 8811.5, 3885.5, 2554.5, 6335.5, 2627.0, 3078.0, 4061.0, 3582.5]

# %% [markdown]
# ### Peaks and Widths for **B=5T** and **T=98K**

# %%
plt.plot(df_B0['5 K'], color="red")

peaks, _ = find_peaks(B0_5K, threshold=55, prominence=2000)

plt.plot(peaks, B0_5K[peaks], "x", color='black')


plt.plot(df_B3['98 K'])
peaks3_b3, _ = find_peaks(B3_98K, threshold=15, prominence=680)
plt.plot(peaks3_b3, B3_98K[peaks3_b3], "x")

# %% [markdown]
# ### Areas Under Peaks for **B=5T** and **T=98K**

# %%
B3_98K_areas = []

area_peak1_B3_98K = np.trapz(B3_98K[276:291], dx=1)
area_peak2_B3_98K = np.trapz(B3_98K[344:357], dx=1)
area_peak3_B3_98K = np.trapz(B3_98K[394:404], dx=1)
area_peak4_B3_98K = np.trapz(B3_98K[603:613], dx=1)
area_peak5_B3_98K = np.trapz(B3_98K[633:644], dx=1)
area_peak6_B3_98K = np.trapz(B3_98K[835:843], dx=1)
area_peak7_B3_98K = np.trapz(B3_98K[1160:1174], dx=1)
area_peak8_B3_98K = np.trapz(B3_98K[1322:1335], dx=1)
area_peak9_B3_98K = np.trapz(B3_98K[1772:1782], dx=1)


#append above to B3_98K_areas
B3_98K_areas.append(area_peak1_B3_98K)
B3_98K_areas.append(area_peak2_B3_98K)
B3_98K_areas.append(area_peak3_B3_98K)
B3_98K_areas.append(area_peak4_B3_98K)
B3_98K_areas.append(area_peak5_B3_98K)
B3_98K_areas.append(area_peak6_B3_98K)
B3_98K_areas.append(area_peak7_B3_98K)
B3_98K_areas.append(area_peak8_B3_98K)
B3_98K_areas.append(area_peak9_B3_98K)

B3_98K_areas
# Out:
# [4845.5, 9950.0, 3997.0, 3392.5, 6878.0, 2681.0, 3349.0, 3821.5, 2503.0]

# %% [markdown]
# ### Peaks and Widths for **B=5T** and **T=118K**

# %%
plt.plot(df_B0['5 K'], color="red")

peaks, _ = find_peaks(B0_5K, threshold=55, prominence=2000)

plt.plot(peaks, B0_5K[peaks], "x", color='black')


plt.plot(df_B3['118 K'])
peaks4_b3, _ = find_peaks(B3_118K, threshold=15, prominence=680)
plt.plot(peaks4_b3, B3_118K[peaks4_b3], "x")

# %% [markdown]
# ### Areas Under Peaks for **B=5T** and **T=118K**

# %%
B3_118K_areas = []

area_peak1_B3_118K = np.trapz(B3_118K[299:311], dx=1)
area_peak2_B3_118K = np.trapz(B3_118K[365:376], dx=1)
area_peak3_B3_118K = np.trapz(B3_118K[413:423], dx=1)
area_peak4_B3_118K = np.trapz(B3_118K[624:633], dx=1)
area_peak5_B3_118K = np.trapz(B3_118K[654:663], dx=1)
area_peak6_B3_118K = np.trapz(B3_118K[854:862], dx=1)
area_peak7_B3_118K = np.trapz(B3_118K[1180:1193], dx=1)
area_peak8_B3_118K = np.trapz(B3_118K[1341:1355], dx=1)
area_peak9_B3_118K = np.trapz(B3_118K[1792:1802], dx=1)


#append above to B3_118K_areas
B3_118K_areas.append(area_peak1_B3_118K)
B3_118K_areas.append(area_peak2_B3_118K)
B3_118K_areas.append(area_peak3_B3_118K)
B3_118K_areas.append(area_peak4_B3_118K)
B3_118K_areas.append(area_peak5_B3_118K)
B3_118K_areas.append(area_peak6_B3_118K)
B3_118K_areas.append(area_peak7_B3_118K)
B3_118K_areas.append(area_peak8_B3_118K)
B3_118K_areas.append(area_peak9_B3_118K)

B3_118K_areas
# Out:
# [4514.0, 9290.0, 4066.5, 3181.5, 6433.0, 2751.5, 3071.5, 3957.0, 2411.0]

# %% [markdown]
# ### Peaks and Widths for **B=5T** and **T=138K**

# %%
plt.plot(df_B0['5 K'], color="red")

peaks, _ = find_peaks(B0_5K, threshold=55, prominence=2000)

plt.plot(peaks, B0_5K[peaks], "x", color='black')


plt.plot(df_B3['138 K'])
peaks5_b3, _ = find_peaks(B3_138K, threshold=15, prominence=680)
plt.plot(peaks5_b3, B3_138K[peaks5_b3], "x")

# %% [markdown]
# ### Areas Under Peaks for **B=5T** and **T=138K**

# %%
B3_138K_areas = []

area_peak1_B3_138K = np.trapz(B3_138K[317:331], dx=1)
area_peak2_B3_138K = np.trapz(B3_138K[385:396], dx=1)
area_peak3_B3_138K = np.trapz(B3_138K[432:442], dx=1)
area_peak4_B3_138K = np.trapz(B3_138K[643:654], dx=1)
area_peak5_B3_138K = np.trapz(B3_138K[672:682], dx=1)
area_peak6_B3_138K = np.trapz(B3_138K[873:882], dx=1)
area_peak7_B3_138K = np.trapz(B3_138K[1201:1212], dx=1)
area_peak8_B3_138K = np.trapz(B3_138K[1362:1374], dx=1)
area_peak9_B3_138K = np.trapz(B3_138K[1812:1821], dx=1)


#append above to B3_138K_areas
B3_138K_areas.append(area_peak1_B3_138K)
B3_138K_areas.append(area_peak2_B3_138K)
B3_138K_areas.append(area_peak3_B3_138K)
B3_138K_areas.append(area_peak4_B3_138K)
B3_138K_areas.append(area_peak5_B3_138K)
B3_138K_areas.append(area_peak6_B3_138K)
B3_138K_areas.append(area_peak7_B3_138K)
B3_138K_areas.append(area_peak8_B3_138K)
B3_138K_areas.append(area_peak9_B3_138K)

B3_138K_areas
# Out:
# [4622.0, 9144.5, 3942.5, 3530.5, 6628.0, 3099.5, 2794.0, 3701.0, 2135.5]

# %% [markdown]
# ### Peaks and Widths for **B=5T** and **T=157K**

# %%
plt.plot(df_B0['5 K'], color="red")

peaks, _ = find_peaks(B0_5K, threshold=55, prominence=2000)

plt.plot(peaks, B0_5K[peaks], "x", color='black')


plt.plot(df_B3['157 K'])
peaks6_b3, _ = find_peaks(B3_157K, threshold=15, prominence=680)
plt.plot(peaks6_b3, B3_157K[peaks6_b3], "x")

# %% [markdown]
# ### Areas Under Peaks for **B=5T** and **T=157K**

# %%
B3_157K_areas = []

area_peak1_B3_157K = np.trapz(B3_157K[338:349], dx=1)
area_peak2_B3_157K = np.trapz(B3_157K[406:416], dx=1)
area_peak3_B3_157K = np.trapz(B3_157K[451:461], dx=1)
area_peak4_B3_157K = np.trapz(B3_157K[665:673], dx=1)
area_peak5_B3_157K = np.trapz(B3_157K[692:701], dx=1)
area_peak6_B3_157K = np.trapz(B3_157K[893:901], dx=1)
area_peak7_B3_157K = np.trapz(B3_157K[1222:1233], dx=1)
area_peak8_B3_157K = np.trapz(B3_157K[1382:1394], dx=1)
area_peak9_B3_157K = np.trapz(B3_157K[1834:1842], dx=1)


#append above to B3_157K_areas
B3_157K_areas.append(area_peak1_B3_157K)
B3_157K_areas.append(area_peak2_B3_157K)
B3_157K_areas.append(area_peak3_B3_157K)
B3_157K_areas.append(area_peak4_B3_157K)
B3_157K_areas.append(area_peak5_B3_157K)
B3_157K_areas.append(area_peak6_B3_157K)
B3_157K_areas.append(area_peak7_B3_157K)
B3_157K_areas.append(area_peak8_B3_157K)
B3_157K_areas.append(area_peak9_B3_157K)

B3_157K_areas
# Out:
# [3982.0, 8609.5, 3951.0, 2752.0, 6568.5, 2964.0, 2738.5, 3662.0, 2083.0]

# %% [markdown]
# ### Peaks and Widths for **B=5T** and **T=177K**

# %%
plt.plot(df_B0['5 K'], color="red")

peaks, _ = find_peaks(B0_5K, threshold=55, prominence=2000)

plt.plot(peaks, B0_5K[peaks], "x", color='black')


plt.plot(df_B3['177 K'])
peaks7_b3, _ = find_peaks(B3_177K, threshold=15, prominence=680)
plt.plot(peaks7_b3, B3_177K[peaks7_b3], "x")

# %% [markdown]
# ### Areas Under Peaks for **B=5T** and **T=177K**

# %%
B3_177K_areas = []

area_peak1_B3_177K = np.trapz(B3_177K[426:436], dx=1)
area_peak2_B3_177K = np.trapz(B3_177K[441:450], dx=1)
area_peak3_B3_177K = np.trapz(B3_177K[470:479], dx=1)
area_peak4_B3_177K = np.trapz(B3_177K[699:707], dx=1)
area_peak5_B3_177K = np.trapz(B3_177K[712:720], dx=1)
area_peak6_B3_177K = np.trapz(B3_177K[905:950], dx=1)
area_peak7_B3_177K = np.trapz(B3_177K[1254:1263], dx=1)
area_peak8_B3_177K = np.trapz(B3_177K[1413:1422], dx=1)
area_peak9_B3_177K = np.trapz(B3_177K[1879:1886], dx=1)


#append above to B3_177K_areas
B3_177K_areas.append(area_peak1_B3_177K)
B3_177K_areas.append(area_peak2_B3_177K)
B3_177K_areas.append(area_peak3_B3_177K)
B3_177K_areas.append(area_peak4_B3_177K)
B3_177K_areas.append(area_peak5_B3_177K)
B3_177K_areas.append(area_peak6_B3_177K)
B3_177K_areas.append(area_peak7_B3_177K)
B3_177K_areas.append(area_peak8_B3_177K)
B3_177K_areas.append(area_peak9_B3_177K)

B3_177K_areas
# Out:
# [6896.5, 9898.0, 3229.5, 6666.5, 5445.5, 8528.5, 6267.5, 5726.0, 6745.0]

# %%
sum(B0_5K_areas)/sum(B3_5K_areas)
# Out:
# 1.1923264769318676

# %% [markdown]
# ### Peaks and Widths for **B=5T** and **T=197K** *(hiç benzemiyor alakasız bir grafik)* *(bu sıcaklıktan sonra sapıtıyor)*

# %%
plt.plot(df_B0['5 K'], color="red")

peaks, _ = find_peaks(B0_5K, threshold=55, prominence=2000)

plt.plot(peaks, B0_5K[peaks], "x", color='black')


plt.plot(df_B3['197 K'])
peaks8_b3, _ = find_peaks(B3_197K, threshold=15, prominence=680)
plt.plot(peaks8_b3, B3_197K[peaks8_b3], "x")

# %% [markdown]
# ### Areas Under Peaks for **B=5T** and **T=197K**

# %%
B3_197K_areas = []

area_peak1_B3_197K = np.trapz(B3_197K[426:436], dx=1)
area_peak2_B3_197K = np.trapz(B3_197K[441:450], dx=1)
area_peak3_B3_197K = np.trapz(B3_197K[470:479], dx=1)
area_peak4_B3_197K = np.trapz(B3_197K[699:707], dx=1)
area_peak5_B3_197K = np.trapz(B3_197K[712:720], dx=1)
area_peak6_B3_197K = np.trapz(B3_197K[905:950], dx=1)
area_peak7_B3_197K = np.trapz(B3_197K[1254:1263], dx=1)
area_peak8_B3_197K = np.trapz(B3_197K[1413:1422], dx=1)
area_peak9_B3_197K = np.trapz(B3_197K[1879:1886], dx=1)


#append above to B3_197K_areas
B3_197K_areas.append(area_peak1_B3_197K)
B3_197K_areas.append(area_peak2_B3_197K)
B3_197K_areas.append(area_peak3_B3_197K)
B3_197K_areas.append(area_peak4_B3_197K)
B3_197K_areas.append(area_peak5_B3_197K)
B3_197K_areas.append(area_peak6_B3_197K)
B3_197K_areas.append(area_peak7_B3_197K)
B3_197K_areas.append(area_peak8_B3_197K)
B3_197K_areas.append(area_peak9_B3_197K)

B3_197K_areas
# Out:
# [790.5, 736.0, 885.0, 579.5, 1445.5, 9338.0, 711.5, 825.0, 612.5]

# %% [markdown]
# ### Peaks and Widths for **B=5T** and **T=218K**

# %%
plt.plot(df_B0['5 K'], color="red")

peaks, _ = find_peaks(B0_5K, threshold=55, prominence=2000)

plt.plot(peaks, B0_5K[peaks], "x", color='black')


plt.plot(df_B3['218 K'])
peaks9_b3, _ = find_peaks(B3_218K, threshold=15, prominence=680)
plt.plot(peaks9_b3, B3_218K[peaks9_b3], "x")

# %% [markdown]
# ### Areas Under Peaks for **B=5T** and **T=218K**

# %%
B3_218K_areas = []

area_peak1_B3_218K = np.trapz(B3_218K[426:436], dx=1)
area_peak2_B3_218K = np.trapz(B3_218K[441:450], dx=1)
area_peak3_B3_218K = np.trapz(B3_218K[470:479], dx=1)
area_peak4_B3_218K = np.trapz(B3_218K[699:707], dx=1)
area_peak5_B3_218K = np.trapz(B3_218K[712:720], dx=1)
area_peak6_B3_218K = np.trapz(B3_218K[905:950], dx=1)
area_peak7_B3_218K = np.trapz(B3_218K[1254:1263], dx=1)
area_peak8_B3_218K = np.trapz(B3_218K[1413:1422], dx=1)
area_peak9_B3_218K = np.trapz(B3_218K[1879:1886], dx=1)


#append above to B3_218K_areas
B3_218K_areas.append(area_peak1_B3_218K)
B3_218K_areas.append(area_peak2_B3_218K)
B3_218K_areas.append(area_peak3_B3_218K)
B3_218K_areas.append(area_peak4_B3_218K)
B3_218K_areas.append(area_peak5_B3_218K)
B3_218K_areas.append(area_peak6_B3_218K)
B3_218K_areas.append(area_peak7_B3_218K)
B3_218K_areas.append(area_peak8_B3_218K)
B3_218K_areas.append(area_peak9_B3_218K)

B3_218K_areas
# Out:
# [689.0, 607.0, 1004.0, 554.5, 544.5, 5947.0, 1482.0, 672.0, 1222.5]

# %% [markdown]
# ### Peaks and Widths for **B=5T** and **T=240K**

# %%
plt.plot(df_B0['5 K'], color="red")

peaks, _ = find_peaks(B0_5K, threshold=55, prominence=2000)

plt.plot(peaks, B0_5K[peaks], "x", color='black')


plt.plot(df_B3['240 K'])
peaks10_b3, _ = find_peaks(B3_240K, threshold=15, prominence=680)
plt.plot(peaks10_b3, B3_240K[peaks10_b3], "x")

# %% [markdown]
# ### Areas Under Peaks for **B=5T** and **T=240K**

# %%
B3_240K_areas = []

area_peak1_B3_240K = np.trapz(B3_240K[426:436], dx=1)
area_peak2_B3_240K = np.trapz(B3_240K[441:450], dx=1)
area_peak3_B3_240K = np.trapz(B3_240K[470:479], dx=1)
area_peak4_B3_240K = np.trapz(B3_240K[699:707], dx=1)
area_peak5_B3_240K = np.trapz(B3_240K[712:720], dx=1)
area_peak6_B3_240K = np.trapz(B3_240K[905:950], dx=1)
area_peak7_B3_240K = np.trapz(B3_240K[1254:1263], dx=1)
area_peak8_B3_240K = np.trapz(B3_240K[1413:1422], dx=1)
area_peak9_B3_240K = np.trapz(B3_240K[1879:1886], dx=1)


#append above to B3_240K_areas
B3_240K_areas.append(area_peak1_B3_240K)
B3_240K_areas.append(area_peak2_B3_240K)
B3_240K_areas.append(area_peak3_B3_240K)
B3_240K_areas.append(area_peak4_B3_240K)
B3_240K_areas.append(area_peak5_B3_240K)
B3_240K_areas.append(area_peak6_B3_240K)
B3_240K_areas.append(area_peak7_B3_240K)
B3_240K_areas.append(area_peak8_B3_240K)
B3_240K_areas.append(area_peak9_B3_240K)

B3_240K_areas
# Out:
# [952.0, 693.0, 688.0, 573.0, 562.5, 5499.0, 590.0, 688.0, 554.0]

# %% [markdown]
# ### Peaks and Widths for **B=5T** and **T=290K**

# %%
plt.plot(df_B0['5 K'], color="red")

peaks, _ = find_peaks(B0_5K, threshold=55, prominence=2000)

plt.plot(peaks, B0_5K[peaks], "x", color='black')


plt.plot(df_B3['290 K'])
peaks11_b3, _ = find_peaks(B3_290K, threshold=15, prominence=680)
plt.plot(peaks11_b3, B3_290K[peaks11_b3], "x")

# %% [markdown]
# ### Areas Under Peaks for **B=5T** and **T=290K**

# %%
B3_290K_areas = []

area_peak1_B3_290K = np.trapz(B3_290K[426:436], dx=1)
area_peak2_B3_290K = np.trapz(B3_290K[441:450], dx=1)
area_peak3_B3_290K = np.trapz(B3_290K[470:479], dx=1)
area_peak4_B3_290K = np.trapz(B3_290K[699:707], dx=1)
area_peak5_B3_290K = np.trapz(B3_290K[712:720], dx=1)
area_peak6_B3_290K = np.trapz(B3_290K[905:950], dx=1)
area_peak7_B3_290K = np.trapz(B3_290K[1254:1263], dx=1)
area_peak8_B3_290K = np.trapz(B3_290K[1413:1422], dx=1)
area_peak9_B3_290K = np.trapz(B3_290K[1879:1886], dx=1)


#append above to B3_290K_areas
B3_290K_areas.append(area_peak1_B3_290K)
B3_290K_areas.append(area_peak2_B3_290K)
B3_290K_areas.append(area_peak3_B3_290K)
B3_290K_areas.append(area_peak4_B3_290K)
B3_290K_areas.append(area_peak5_B3_290K)
B3_290K_areas.append(area_peak6_B3_290K)
B3_290K_areas.append(area_peak7_B3_290K)
B3_290K_areas.append(area_peak8_B3_290K)
B3_290K_areas.append(area_peak9_B3_290K)

B3_290K_areas
# Out:
# [877.0, 2515.0, 640.5, 585.5, 606.0, 5250.5, 706.5, 679.5, 615.5]

# %%
import matplotlib.pyplot as plt
x_ax = [1,2,3,4,5,6,7,8,9]

# plotting the line 1 points 
plt.plot(x_ax, B0_5K_areas, label = "B0-5K")
plt.plot(x_ax, B0_94K_areas, label = "B3-98K")
plt.plot(x_ax, B0_117K_areas, label = "B0-94K")
plt.plot(x_ax, B0_137K_areas, label = "B0-94K")
plt.plot(x_ax, B0_158K_areas, label = "B0-94K")
plt.plot(x_ax, B0_180K_areas, label = "B0-94K")
plt.plot(x_ax, B0_203K_areas, label = "B0-94K")

plt.xlabel('Peak number')
# Set the y axis label of the current axis.
plt.ylabel('Area')
# Set a title of the current axes.
plt.title('Areas under peaks for B0-5K and B3-177K')
plt.legend()

# %%
import matplotlib.pyplot as plt
B0_temp = [94,117,137,158,180,203,227,253]





# plotting the line 1 points 
plt.plot(x_ax, B0_5K_areas, label = "B0-5K")
plt.plot(x_ax, B0_94K_areas, label = "B3-98K")
plt.plot(x_ax, B0_117K_areas, label = "B0-94K")
plt.plot(x_ax, B0_137K_areas, label = "B0-94K")
plt.plot(x_ax, B0_158K_areas, label = "B0-94K")
plt.plot(x_ax, B0_180K_areas, label = "B0-94K")
plt.plot(x_ax, B0_203K_areas, label = "B0-94K")

plt.xlabel('Peak number')
# Set the y axis label of the current axis.
plt.ylabel('Area')
# Set a title of the current axes.
plt.title('Areas under peaks for B0-5K and B3-177K')
plt.legend()

# %%
B0_first_peaks = []


B0_first_peaks.append(B0_94K_areas[0])
B0_first_peaks.append(B0_117K_areas[0])
B0_first_peaks.append(B0_137K_areas[0])
B0_first_peaks.append(B0_158K_areas[0])
B0_first_peaks.append(B0_180K_areas[0])
B0_first_peaks.append(B0_203K_areas[0])
B0_first_peaks.append(B0_227K_areas[0])
B0_first_peaks.append(B0_253K_areas[0])

B0_first_peaks
# Out:
# [4662.5, 4547.0, 4463.0, 4406.5, 4579.0, 5063.5, 4483.0, 4291.0]

# %%
B0_temp = [94,117,137,158,180,203,227,253]
plt.plot(B0_temp, B0_first_peaks, marker='o')
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under first peaks for B=0 and B=5T")

plt.plot(B3_temp, B3_first_peaks, color='red', marker='o')
#add legend to plot
plt.legend(['B=0T', 'B=5T'])

plt.yticks([])
plt.savefig('B0_first_peaksSON.png')

# %%
# plt.plot(B0_2Theta, B0_290K)
# plt.xlabel('2ϴ / Degrees')
# plt.ylabel('Intensity')
# plt.plot(B3_2Theta, B3_290K)
# plt.title("Comparison between neutron scattering data for 290K at B=0 and B=5T")
# plt.legend(['B=0T', 'B=5T'])
# plt.yticks([])

fig, (ax1, ax2) = plt.subplots(2)
fig.suptitle('Comparison between neutron diffraction data for T=290K at B=0T and B=5T')
ax1.plot(B0_2Theta, B0_290K, color='blue')
ax1.set_yticks([])

ax2.plot(B3_2Theta, B3_290K, color='red')
fig.text(0.5, 0.04, '2ϴ / Degrees', ha='center', va='center')
fig.text(0.06, 0.5, 'Intensity', ha='center', va='center', rotation='vertical')

plt.yticks([])

ax1.legend(["B=0T"],loc= "upper right")
ax2.legend(["B=5T"],loc="upper right")



# plt.plot(B0_2Theta,B0_5K)

# peaks, _ = find_peaks(B0_5K, threshold=55, prominence=2000)
# plt.plot(B0_2Theta[peaks], B0_5K[peaks], "x")


# plt.yticks([])

# %%
fig, (ax1, ax2) = plt.subplots(2)
fig.suptitle('Comparison between neutron diffraction data for T=5K at B=0T and B=5T')
ax1.plot(B0_2Theta, B0_5K, color='blue')
ax1.set_yticks([])

ax2.plot(B3_2Theta, B3_5K, color='red')
fig.text(0.5, 0.04, '2ϴ / Degrees', ha='center', va='center')
fig.text(0.06, 0.5, 'Intensity', ha='center', va='center', rotation='vertical')

plt.yticks([])

ax1.legend(["B=0T"],loc= "upper right")
ax2.legend(["B=5T"],loc="upper right")

# %%
fig, (ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10) = plt.subplots(10)
# fig.suptitle('Neutron diffraction data for B=0T and varying temperatures')

ax1.plot(B0_2Theta, B0_5K, color='black')
ax1.set_yticks([])
ax1.set_xticks([])
ax1.legend(["T=5K"],loc= "upper right")
ax1.set_title('Neutron diffraction data for B=0 T and temperatures from T=5 K to T=290 K')

ax2.plot(B0_2Theta, B0_94K, color='blue')
ax2.set_yticks([])
ax2.set_xticks([])
ax2.legend(["T=94K"],loc= "upper right")

ax3.plot(B0_2Theta, B0_117K, color='purple')
ax3.set_yticks([])
ax3.set_xticks([])
ax3.legend(["T=117K"],loc= "upper right")

ax4.plot(B0_2Theta, B0_137K, color='green')
ax4.set_yticks([])
ax4.set_xticks([])
ax4.legend(["T=137K"],loc= "upper right")

ax5.plot(B0_2Theta, B0_158K, color='red')
ax5.set_yticks([])
ax5.set_xticks([])
ax5.legend(["T=158K"],loc= "upper right")

ax6.plot(B0_2Theta, B0_180K, color='cyan')
ax6.set_yticks([])
ax6.set_xticks([])
ax6.legend(["T=180K"],loc= "upper right")

ax7.plot(B0_2Theta, B0_203K, color='magenta')
ax7.set_yticks([])
ax7.set_xticks([])
ax7.legend(["T=203K"],loc= "upper right")

ax8.plot(B0_2Theta, B0_227K, color='orange')
ax8.set_yticks([])
ax8.set_xticks([])
ax8.legend(["T=227K"],loc= "upper right")


ax9.plot(B0_2Theta, B0_253K, color='red')
ax9.set_yticks([])
ax9.set_xticks([])
ax9.legend(["T=253K"],loc= "upper right")

ax10.plot(B0_2Theta, B0_290K, color='black')
ax10.set_xlabel('2ϴ / Degrees')
ax10.set_yticks([])
ax10.legend(["T=290K"],loc= "upper right")



# fig.text(0.5, 0.04, '2ϴ / Degrees', ha='center', va='center')
fig.text(0.06, 0.5, 'Intensity', ha='center', va='center', rotation='vertical')

fig.set_figheight(10)
fig.set_figwidth(10)



# ax1.legend(["B=0T"],loc= "upper right")
# ax2.legend(["B=5T"],loc="upper right")

# %%
fig, (ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10) = plt.subplots(10)
# fig.suptitle('Neutron diffraction data for B=0T and varying temperatures')

ax1.plot(B3_2Theta, B3_5K, color='black')
ax1.set_yticks([])
ax1.set_xticks([])
ax1.legend(["T=5K"],loc= "upper right")
ax1.set_title('Neutron diffraction data for B=5T and varying temperatures')

ax2.plot(B3_2Theta, B3_76K, color='blue')
ax2.set_yticks([])
ax2.set_xticks([])
ax2.legend(["T=76K"],loc= "upper right")

ax3.plot(B3_2Theta, B3_118K, color='purple')
ax3.set_yticks([])
ax3.set_xticks([])
ax3.legend(["T=118K"],loc= "upper right")

ax4.plot(B3_2Theta, B3_138K, color='green')
ax4.set_yticks([])
ax4.set_xticks([])
ax4.legend(["T=138K"],loc= "upper right")

ax5.plot(B0_2Theta, B3_157K, color='red')
ax5.set_yticks([])
ax5.set_xticks([])
ax5.legend(["T=157K"],loc= "upper right")

ax6.plot(B0_2Theta, B3_177K, color='cyan')
ax6.set_yticks([])
ax6.set_xticks([])
ax6.legend(["T=177K"],loc= "upper right")

ax7.plot(B0_2Theta, B3_197K, color='magenta')
ax7.set_yticks([])
ax7.set_xticks([])
ax7.legend(["T=197K"],loc= "upper right")

ax8.plot(B0_2Theta, B3_218K, color='orange')
ax8.set_yticks([])
ax8.set_xticks([])
ax8.legend(["T=218K"],loc= "upper right")

ax9.plot(B0_2Theta, B3_240K, color='red')
ax9.set_yticks([])
ax9.set_xticks([])
ax9.legend(["T=240K"],loc= "upper right")

ax10.plot(B0_2Theta, B3_290K, color='black')
ax10.set_xlabel('2ϴ / Degrees')
ax10.set_yticks([])
ax10.legend(["T=290K"],loc= "upper right")



# fig.text(0.5, 0.04, '2ϴ / Degrees', ha='center', va='center')
fig.text(0.06, 0.5, 'Intensity', ha='center', va='center', rotation='vertical')

fig.set_figheight(10)
fig.set_figwidth(10)

# %%
figure, axis = plt.subplots(3, 3)
figure.suptitle('Areas under the peaks for neutron diffraction data for B=0T and varying temperatures')

# plt.scatter(B0_temp, B0_first_peaks)
# plt.xlabel('Temperature (K)')
# # Set the y axis label of the current axis.
# plt.ylabel('Area (a.u.)')

axis[0, 0].plot(B0_temp, B0_first_peaks, marker='o')
axis[0, 0].set_title("Peak 1")
# axis[0, 0].set_xticks([])
axis[0, 0].set_yticks([])


axis[0, 1].plot(B0_temp, B0_second_peaks, marker='o')
axis[0, 1].set_title("Peak 2")
# axis[0, 1].set_xticks([])
axis[0, 1].set_yticks([])

axis[0, 2].plot(B0_temp, B0_third_peaks, marker='o')
axis[0, 2].set_title("Peak 3")
# axis[0, 2].set_xticks([])
axis[0, 2].set_yticks([])
  
axis[1, 0].plot(B0_temp, B0_fourth_peaks, marker='o')
axis[1, 0].set_title("Peak 4")
# axis[1, 0].set_xticks([])
axis[1, 0].set_yticks([])

axis[1, 1].plot(B0_temp, B0_fifth_peaks, marker='o')
axis[1, 1].set_title("Peak 5")
# axis[1, 1].set_xticks([])
axis[1, 1].set_yticks([])

axis[1, 2].plot(B0_temp, B0_sixth_peaks, marker='o')
axis[1, 2].set_title("Peak 6")
# axis[1, 2].set_xticks([])
axis[1, 2].set_yticks([])

axis[2, 0].plot(B0_temp, B0_seventh_peaks, marker='o')
axis[2, 0].set_title("Peak 7")
# axis[2, 0].set_xticks([])
axis[2, 0].set_yticks([])

axis[2, 1].plot(B0_temp, B0_eight_peaks, marker='o')
axis[2, 1].set_title("Peak 8")
# axis[2, 1].set_xticks([])
axis[2, 1].set_yticks([])

axis[2, 2].plot(B0_temp, B0_ninth_peaks, marker='o')
axis[2, 2].set_title("Peak 9")
# axis[2, 2].set_xticks([])
axis[2, 2].set_yticks([])

figure.tight_layout(pad=2.0)
figure.text(0.5, 0.04, 'Temperature (K)', ha='center', va='center')
figure.text(0.02, 0.5, 'Area (a.u.)', ha='center', va='center', rotation='vertical')
# Out:
# Text(0.02,0.5,'Area (a.u.)')

# %%
B3_first_peaks
# Out:
# array([3784.5, 4845.5, 4514. , 4622. , 3982. , 6896.5,  790.5,  689. ])

# %%
figure, axis = plt.subplots(3, 3, figsize=(9,7))
figure.suptitle('Areas under the peaks for neutron diffraction data for B=0T and B=5T', y=1.0)

B0_temp1 = [94,117,137,158,180,203,227,253]

axis[0, 0].plot(B0_temp1, B0_first_peaks, marker='o')
axis[0, 0].plot(B3_temp, B3_first_peaks, marker='o')
axis[0, 0].set_title("Peak 1")
# axis[0, 0].set_xticks([])
axis[0, 0].set_yticks([])
axis[0, 0].legend(['B=0T', 'B=5T'], prop={'size': 6})


axis[0, 1].plot(B0_temp1, B0_second_peaks, marker='o')
axis[0, 1].plot(B3_temp, B3_second_peaks, marker='o')
axis[0, 1].set_title("Peak 2")
# axis[0, 1].set_xticks([])
axis[0, 1].set_yticks([])
axis[0, 1].legend(['B=0T', 'B=5T'], prop={'size': 6})

axis[0, 2].plot(B0_temp1, B0_third_peaks, marker='o')
axis[0, 2].plot(B3_temp, B3_third_peaks, marker='o')
axis[0, 2].set_title("Peak 3")
# axis[0, 2].set_xticks([])
axis[0, 2].set_yticks([])
axis[0, 2].legend(['B=0T', 'B=5T'], prop={'size': 6})
  
axis[1, 0].plot(B0_temp1, B0_fourth_peaks, marker='o')
axis[1, 0].plot(B3_temp, B3_fourth_peaks, marker='o')
axis[1, 0].set_title("Peak 4")
# axis[1, 0].set_xticks([])
axis[1, 0].set_yticks([])
axis[1, 0].legend(['B=0T', 'B=5T'], prop={'size': 6})

axis[1, 1].plot(B0_temp1, B0_fifth_peaks, marker='o')
axis[1, 1].plot(B3_temp, B3_fifth_peaks, marker='o')
axis[1, 1].set_title("Peak 5")
# axis[1, 1].set_xticks([])
axis[1, 1].set_yticks([])
axis[1, 1].legend(['B=0T', 'B=5T'], prop={'size': 6})

axis[1, 2].plot(B0_temp1, B0_sixth_peaks, marker='o')
axis[1, 2].plot(B3_temp, B3_sixth_peaks, marker='o')
axis[1, 2].set_title("Peak 6")
# axis[1, 2].set_xticks([])
axis[1, 2].set_yticks([])
axis[1, 2].legend(['B=0T', 'B=5T'], prop={'size': 6})

axis[2, 0].plot(B0_temp1, B0_seventh_peaks, marker='o')
axis[2, 0].plot(B3_temp, B3_seventh_peaks, marker='o')
axis[2, 0].set_title("Peak 7")
# axis[2, 0].set_xticks([])
axis[2, 0].set_yticks([])
axis[2, 0].legend(['B=0T', 'B=5T'], prop={'size': 6})

axis[2, 1].plot(B0_temp1, B0_eight_peaks, marker='o')
axis[2, 1].plot(B3_temp, B3_eight_peaks, marker='o')
axis[2, 1].set_title("Peak 8")
# axis[2, 1].set_xticks([])
axis[2, 1].set_yticks([])
axis[2, 1].legend(['B=0T', 'B=5T'], prop={'size': 6})

axis[2, 2].plot(B0_temp1, B0_ninth_peaks, marker='o')
axis[2, 2].plot(B3_temp, B3_ninth_peaks, marker='o')
axis[2, 2].set_title("Peak 9")
# axis[2, 2].set_xticks([])
axis[2, 2].set_yticks([])
axis[2, 2].legend(['B=0T', 'B=5T'], prop={'size': 6})

figure.tight_layout(pad=2.0)
figure.text(0.5, 0.02, 'Temperature (K)', ha='center', va='center')
figure.text(0.02, 0.5, 'Area (a.u.)', ha='center', va='center', rotation='vertical')
# Out:
# Text(0.02,0.5,'Area (a.u.)')

# %%
figure, axis = plt.subplots(3, 3, figsize=(9,7))
figure.suptitle('Areas under the peaks for neutron diffraction data for B=0T and B=5T', y=1.0)


B0_temp1 = [94,117,137]
B0_temp1 = np.array(B0_temp1)
B0_first_peaks_temp= []
B0_second_peaks_temp= []
B0_third_peaks_temp= []
B0_fourth_peaks_temp= []
B0_fifth_peaks_temp= []
B0_sixth_peaks_temp= []
B0_seventh_peaks_temp= []
B0_eight_peaks_temp= []
B0_ninth_peaks_temp= []


B3_temp = [76,98,118]
B3_temp = np.array(B3_temp)
B3_first_peaks_temp= []
B3_second_peaks_temp= []
B3_third_peaks_temp= []
B3_fourth_peaks_temp= []
B3_fifth_peaks_temp= []
B3_sixth_peaks_temp= []
B3_seventh_peaks_temp= []
B3_eight_peaks_temp= []
B3_ninth_peaks_temp= []



for i in range (0,3):
    B0_first_peaks_temp.append(B0_first_peaks[i])
    B0_second_peaks_temp.append(B0_second_peaks[i])
    B0_third_peaks_temp.append(B0_third_peaks[i])
    B0_fourth_peaks_temp.append(B0_fourth_peaks[i])
    B0_fifth_peaks_temp.append(B0_fifth_peaks[i])
    B0_sixth_peaks_temp.append(B0_sixth_peaks[i])
    B0_seventh_peaks_temp.append(B0_seventh_peaks[i])
    B0_eight_peaks_temp.append(B0_eight_peaks[i])
    B0_ninth_peaks_temp.append(B0_ninth_peaks[i])

    B3_first_peaks_temp.append(B3_first_peaks[i])
    B3_second_peaks_temp.append(B3_second_peaks[i])
    B3_third_peaks_temp.append(B3_third_peaks[i])
    B3_fourth_peaks_temp.append(B3_fourth_peaks[i])
    B3_fifth_peaks_temp.append(B3_fifth_peaks[i])
    B3_sixth_peaks_temp.append(B3_sixth_peaks[i])
    B3_seventh_peaks_temp.append(B3_seventh_peaks[i])
    B3_eight_peaks_temp.append(B3_eight_peaks[i])
    B3_ninth_peaks_temp.append(B3_ninth_peaks[i])




axis[0, 0].plot(B0_temp1, B0_first_peaks_temp, marker='o')
axis[0, 0].plot(B3_temp, B3_first_peaks_temp, marker='o')
axis[0, 0].set_title("Peak 1")
# axis[0, 0].set_xticks([])
axis[0, 0].set_yticks([])
axis[0, 0].legend(['B=0T', 'B=5T'], prop={'size': 6})


axis[0, 1].plot(B0_temp1, B0_second_peaks_temp, marker='o')
axis[0, 1].plot(B3_temp, B3_second_peaks_temp, marker='o')
axis[0, 1].set_title("Peak 2")
# axis[0, 1].set_xticks([])
axis[0, 1].set_yticks([])
axis[0, 1].legend(['B=0T', 'B=5T'], prop={'size': 6})

axis[0, 2].plot(B0_temp1, B0_third_peaks_temp, marker='o')
axis[0, 2].plot(B3_temp, B3_third_peaks_temp, marker='o')
axis[0, 2].set_title("Peak 3")
# axis[0, 2].set_xticks([])
axis[0, 2].set_yticks([])
axis[0, 2].legend(['B=0T', 'B=5T'], prop={'size': 6})
  
axis[1, 0].plot(B0_temp1, B0_fourth_peaks_temp, marker='o')
axis[1, 0].plot(B3_temp, B3_fourth_peaks_temp, marker='o')
axis[1, 0].set_title("Peak 4")
# axis[1, 0].set_xticks([])
axis[1, 0].set_yticks([])
axis[1, 0].legend(['B=0T', 'B=5T'], prop={'size': 6})

axis[1, 1].plot(B0_temp1, B0_fifth_peaks_temp, marker='o')
axis[1, 1].plot(B3_temp, B3_fifth_peaks_temp, marker='o')
axis[1, 1].set_title("Peak 5")
# axis[1, 1].set_xticks([])
axis[1, 1].set_yticks([])
axis[1, 1].legend(['B=0T', 'B=5T'], prop={'size': 6})

axis[1, 2].plot(B0_temp1, B0_sixth_peaks_temp, marker='o')
axis[1, 2].plot(B3_temp, B3_sixth_peaks_temp, marker='o')
axis[1, 2].set_title("Peak 6")
# axis[1, 2].set_xticks([])
axis[1, 2].set_yticks([])
axis[1, 2].legend(['B=0T', 'B=5T'], prop={'size': 6})

axis[2, 0].plot(B0_temp1, B0_seventh_peaks_temp, marker='o')
axis[2, 0].plot(B3_temp, B3_seventh_peaks_temp, marker='o')
axis[2, 0].set_title("Peak 7")
# axis[2, 0].set_xticks([])
axis[2, 0].set_yticks([])
axis[2, 0].legend(['B=0T', 'B=5T'], prop={'size': 6})

axis[2, 1].plot(B0_temp1, B0_eight_peaks_temp, marker='o')
axis[2, 1].plot(B3_temp, B3_eight_peaks_temp, marker='o')
axis[2, 1].set_title("Peak 8")
# axis[2, 1].set_xticks([])
axis[2, 1].set_yticks([])
axis[2, 1].legend(['B=0T', 'B=5T'], prop={'size': 6})

axis[2, 2].plot(B0_temp1, B0_ninth_peaks_temp, marker='o')
axis[2, 2].plot(B3_temp, B3_ninth_peaks_temp, marker='o')
axis[2, 2].set_title("Peak 9")
# axis[2, 2].set_xticks([])
axis[2, 2].set_yticks([])
axis[2, 2].legend(['B=0T', 'B=5T'], prop={'size': 6})

figure.tight_layout(pad=2.0)
figure.text(0.5, 0.02, 'Temperature (K)', ha='center', va='center')
figure.text(0.02, 0.5, 'Area (a.u.)', ha='center', va='center', rotation='vertical')

axis[0, 0].set_ylim([0,6500])
axis[0, 1].set_ylim([0,20000])
axis[0, 2].set_ylim([0,10000])
axis[1, 0].set_ylim([0,9000])
axis[1, 1].set_ylim([0,16000])
axis[1, 2].set_ylim([0,12000])
axis[2, 0].set_ylim([0,15000])
axis[2, 1].set_ylim([0,12000])
axis[2, 2].set_ylim([0,15000])
# Out:
# (0, 15000)

# %%
figure, axis = plt.subplots(3, 3, figsize=(9,7))
figure.suptitle('Areas under the peaks for neutron diffraction data for B=0T and B=5T', y=1.0)

B0_temp1 = [158,180,203,227]
B0_temp1 = np.array(B0_temp1)
B0_first_peaks_temp= []
B0_second_peaks_temp= []
B0_third_peaks_temp= []
B0_fourth_peaks_temp= []
B0_fifth_peaks_temp= []
B0_sixth_peaks_temp= []
B0_seventh_peaks_temp= []
B0_eight_peaks_temp= []
B0_ninth_peaks_temp= []


B3_temp = [157,177,197,218]
B3_temp = np.array(B3_temp)
B3_first_peaks_temp= []
B3_second_peaks_temp= []
B3_third_peaks_temp= []
B3_fourth_peaks_temp= []
B3_fifth_peaks_temp= []
B3_sixth_peaks_temp= []
B3_seventh_peaks_temp= []
B3_eight_peaks_temp= []
B3_ninth_peaks_temp= []



for i in range (3,7):
    B0_first_peaks_temp.append(B0_first_peaks[i])
    B0_second_peaks_temp.append(B0_second_peaks[i])
    B0_third_peaks_temp.append(B0_third_peaks[i])
    B0_fourth_peaks_temp.append(B0_fourth_peaks[i])
    B0_fifth_peaks_temp.append(B0_fifth_peaks[i])
    B0_sixth_peaks_temp.append(B0_sixth_peaks[i])
    B0_seventh_peaks_temp.append(B0_seventh_peaks[i])
    B0_eight_peaks_temp.append(B0_eight_peaks[i])
    B0_ninth_peaks_temp.append(B0_ninth_peaks[i])
for i in range (4,8):
    B3_first_peaks_temp.append(B3_first_peaks[i])
    B3_second_peaks_temp.append(B3_second_peaks[i])
    B3_third_peaks_temp.append(B3_third_peaks[i])
    B3_fourth_peaks_temp.append(B3_fourth_peaks[i])
    B3_fifth_peaks_temp.append(B3_fifth_peaks[i])
    B3_sixth_peaks_temp.append(B3_sixth_peaks[i])
    B3_seventh_peaks_temp.append(B3_seventh_peaks[i])
    B3_eight_peaks_temp.append(B3_eight_peaks[i])
    B3_ninth_peaks_temp.append(B3_ninth_peaks[i])




axis[0, 0].plot(B0_temp1, B0_first_peaks_temp, marker='o')
axis[0, 0].plot(B3_temp, B3_first_peaks_temp, marker='o')
axis[0, 0].set_title("Peak 1")
# axis[0, 0].set_xticks([])
axis[0, 0].set_yticks([])
axis[0, 0].legend(['B=0T', 'B=5T'], prop={'size': 6})


axis[0, 1].plot(B0_temp1, B0_second_peaks_temp, marker='o')
axis[0, 1].plot(B3_temp, B3_second_peaks_temp, marker='o')
axis[0, 1].set_title("Peak 2")
# axis[0, 1].set_xticks([])
axis[0, 1].set_yticks([])
axis[0, 1].legend(['B=0T', 'B=5T'], prop={'size': 6})

axis[0, 2].plot(B0_temp1, B0_third_peaks_temp, marker='o')
axis[0, 2].plot(B3_temp, B3_third_peaks_temp, marker='o')
axis[0, 2].set_title("Peak 3")
# axis[0, 2].set_xticks([])
axis[0, 2].set_yticks([])
axis[0, 2].legend(['B=0T', 'B=5T'], prop={'size': 6})
  
axis[1, 0].plot(B0_temp1, B0_fourth_peaks_temp, marker='o')
axis[1, 0].plot(B3_temp, B3_fourth_peaks_temp, marker='o')
axis[1, 0].set_title("Peak 4")
# axis[1, 0].set_xticks([])
axis[1, 0].set_yticks([])
axis[1, 0].legend(['B=0T', 'B=5T'], prop={'size': 6})

axis[1, 1].plot(B0_temp1, B0_fifth_peaks_temp, marker='o')
axis[1, 1].plot(B3_temp, B3_fifth_peaks_temp, marker='o')
axis[1, 1].set_title("Peak 5")
# axis[1, 1].set_xticks([])
axis[1, 1].set_yticks([])
axis[1, 1].legend(['B=0T', 'B=5T'], prop={'size': 6})

axis[1, 2].plot(B0_temp1, B0_sixth_peaks_temp, marker='o')
axis[1, 2].plot(B3_temp, B3_sixth_peaks_temp, marker='o')
axis[1, 2].set_title("Peak 6")
# axis[1, 2].set_xticks([])
axis[1, 2].set_yticks([])
axis[1, 2].legend(['B=0T', 'B=5T'], prop={'size': 6})

axis[2, 0].plot(B0_temp1, B0_seventh_peaks_temp, marker='o')
axis[2, 0].plot(B3_temp, B3_seventh_peaks_temp, marker='o')
axis[2, 0].set_title("Peak 7")
# axis[2, 0].set_xticks([])
axis[2, 0].set_yticks([])
axis[2, 0].legend(['B=0T', 'B=5T'], prop={'size': 6})

axis[2, 1].plot(B0_temp1, B0_eight_peaks_temp, marker='o')
axis[2, 1].plot(B3_temp, B3_eight_peaks_temp, marker='o')
axis[2, 1].set_title("Peak 8")
# axis[2, 1].set_xticks([])
axis[2, 1].set_yticks([])
axis[2, 1].legend(['B=0T', 'B=5T'], prop={'size': 6})

axis[2, 2].plot(B0_temp1, B0_ninth_peaks_temp, marker='o')
axis[2, 2].plot(B3_temp, B3_ninth_peaks_temp, marker='o')
axis[2, 2].set_title("Peak 9")
# axis[2, 2].set_xticks([])
axis[2, 2].set_yticks([])
axis[2, 2].legend(['B=0T', 'B=5T'], prop={'size': 6})

figure.tight_layout(pad=2.0)
figure.text(0.5, 0.02, 'Temperature (K)', ha='center', va='center')
figure.text(0.02, 0.5, 'Area (a.u.)', ha='center', va='center', rotation='vertical')
axis[0, 0].set_ylim([0,10000])
axis[0, 1].set_ylim([0,20000])
axis[0, 2].set_ylim([0,6000])
axis[1, 0].set_ylim([0,9000])
axis[1, 1].set_ylim([0,18000])
axis[1, 2].set_ylim([0,12000])
axis[2, 0].set_ylim([0,15000])
axis[2, 1].set_ylim([0,12000])
axis[2, 2].set_ylim([0,15000])
# Out:
# (0, 15000)

# %%
figure, axis = plt.subplots(3, 3, figsize=(9,9))
figure.suptitle('The change trend of the areas under the peaks in the absence of the magnetic field', y=1.00)

B0_temp = [94,117,137]
B0_temp = np.array(B0_temp)
B0_first_peaks_temp= []
B0_second_peaks_temp= []
B0_third_peaks_temp= []
B0_fourth_peaks_temp= []
B0_fifth_peaks_temp= []
B0_sixth_peaks_temp= []
B0_seventh_peaks_temp= []
B0_eight_peaks_temp= []
B0_ninth_peaks_temp= []


for i in range (0,3):
    B0_first_peaks_temp.append(B0_first_peaks[i])
    B0_second_peaks_temp.append(B0_second_peaks[i])
    B0_third_peaks_temp.append(B0_third_peaks[i])
    B0_fourth_peaks_temp.append(B0_fourth_peaks[i])
    B0_fifth_peaks_temp.append(B0_fifth_peaks[i])
    B0_sixth_peaks_temp.append(B0_sixth_peaks[i])
    B0_seventh_peaks_temp.append(B0_seventh_peaks[i])
    B0_eight_peaks_temp.append(B0_eight_peaks[i])
    B0_ninth_peaks_temp.append(B0_ninth_peaks[i])





axis[0, 0].plot(B0_temp, B0_first_peaks_temp, marker='o')
# m, b = np.polyfit(B0_temp, B0_first_peaks_temp, 1)
# axis[0, 0].plot(B0_temp, m*B0_temp + b)
axis[0, 0].set_title("Peak 1")
axis[0, 0].set_yticks([])



axis[0, 1].plot(B0_temp, B0_second_peaks_temp, marker='o')
# m, b = np.polyfit(B0_temp, B0_second_peaks_temp, 1)
# axis[0, 1].plot(B0_temp, m*B0_temp + b)
axis[0, 1].set_title("Peak 2")
axis[0, 1].set_yticks([])


axis[0, 2].plot(B0_temp, B0_third_peaks_temp, marker='o')
# m, b = np.polyfit(B0_temp, B0_third_peaks_temp, 1)
# axis[0, 2].plot(B0_temp, m*B0_temp + b)
axis[0, 2].set_title("Peak 3")
axis[0, 2].set_yticks([])


axis[1, 0].plot(B0_temp, B0_fourth_peaks_temp, marker='o')
# m, b = np.polyfit(B0_temp, B0_fourth_peaks_temp, 1)
# axis[1, 0].plot(B0_temp, m*B0_temp + b)
axis[1, 0].set_title("Peak 4")
axis[1, 0].set_yticks([])

axis[1, 1].plot(B0_temp, B0_fifth_peaks_temp, marker='o')
# m, b = np.polyfit(B0_temp, B0_fifth_peaks_temp, 1)
# axis[1, 1].plot(B0_temp, m*B0_temp + b)
axis[1, 1].set_title("Peak 5")
axis[1, 1].set_yticks([])


axis[1, 2].plot(B0_temp, B0_sixth_peaks_temp, marker='o')
# m, b = np.polyfit(B0_temp, B0_sixth_peaks_temp, 1)
# axis[1, 2].plot(B0_temp, m*B0_temp + b)
axis[1, 2].set_title("Peak 6")
axis[1, 2].set_yticks([])


axis[2, 0].plot(B0_temp, B0_seventh_peaks_temp, marker='o')
# m, b = np.polyfit(B0_temp, B0_seventh_peaks_temp, 1)
# axis[2, 0].plot(B0_temp, m*B0_temp + b)
axis[2, 0].set_title("Peak 7")
axis[2, 0].set_yticks([])


axis[2, 1].plot(B0_temp, B0_eight_peaks_temp, marker='o')
# m, b = np.polyfit(B0_temp, B0_eight_peaks_temp, 1)
# axis[2, 1].plot(B0_temp, m*B0_temp + b)
axis[2, 1].set_title("Peak 8")
axis[2, 1].set_yticks([])


axis[2, 2].plot(B0_temp, B0_ninth_peaks_temp, marker='o')
# m, b = np.polyfit(B0_temp, B0_ninth_peaks_temp, 1)
# axis[2, 2].plot(B0_temp, m*B0_temp + b)
axis[2, 2].set_title("Peak 9")
axis[2, 2].set_yticks([])


figure.tight_layout(pad=2.0)



figure.text(0.5, 0.002, 'Temperature (K)', ha='center', va='center')
figure.text(0.02, 0.5, 'Area (a.u.)', ha='center', va='center', rotation='vertical')

axis[0, 0].set_ylim([0,6500])
axis[0, 1].set_ylim([0,20000])
axis[0, 2].set_ylim([0,10000])
axis[1, 0].set_ylim([0,9000])
axis[1, 1].set_ylim([0,16000])
axis[1, 2].set_ylim([0,12000])
axis[2, 0].set_ylim([0,15000])
axis[2, 1].set_ylim([0,12000])
axis[2, 2].set_ylim([0,15000])
# Out:
# (0, 15000)

# %%
figure, axis = plt.subplots(3, 3, figsize=(9,7))
figure.suptitle('The change trend of the areas under the peaks in the absence of the magnetic field', y=1.00)

B0_temp = [158,180,203,227,253]
B0_temp = np.array(B0_temp)
B0_first_peaks_temp= []
B0_second_peaks_temp= []
B0_third_peaks_temp= []
B0_fourth_peaks_temp= []
B0_fifth_peaks_temp= []
B0_sixth_peaks_temp= []
B0_seventh_peaks_temp= []
B0_eight_peaks_temp= []
B0_ninth_peaks_temp= []


for i in range (3,8):
    B0_first_peaks_temp.append(B0_first_peaks[i])
    B0_second_peaks_temp.append(B0_second_peaks[i])
    B0_third_peaks_temp.append(B0_third_peaks[i])
    B0_fourth_peaks_temp.append(B0_fourth_peaks[i])
    B0_fifth_peaks_temp.append(B0_fifth_peaks[i])
    B0_sixth_peaks_temp.append(B0_sixth_peaks[i])
    B0_seventh_peaks_temp.append(B0_seventh_peaks[i])
    B0_eight_peaks_temp.append(B0_eight_peaks[i])
    B0_ninth_peaks_temp.append(B0_ninth_peaks[i])





axis[0, 0].plot(B0_temp, B0_first_peaks_temp, marker='o')
# m, b = np.polyfit(B0_temp, B0_first_peaks_temp, 1)
# axis[0, 0].plot(B0_temp, m*B0_temp + b)
axis[0, 0].set_title("Peak 1")
axis[0, 0].set_yticks([])



axis[0, 1].plot(B0_temp, B0_second_peaks_temp, marker='o')
# m, b = np.polyfit(B0_temp, B0_second_peaks_temp, 1)
# axis[0, 1].plot(B0_temp, m*B0_temp + b)
axis[0, 1].set_title("Peak 2")
axis[0, 1].set_yticks([])


axis[0, 2].plot(B0_temp, B0_third_peaks_temp, marker='o')
# m, b = np.polyfit(B0_temp, B0_third_peaks_temp, 1)
# axis[0, 2].plot(B0_temp, m*B0_temp + b)
axis[0, 2].set_title("Peak 3")
axis[0, 2].set_yticks([])


axis[1, 0].plot(B0_temp, B0_fourth_peaks_temp, marker='o')
# m, b = np.polyfit(B0_temp, B0_fourth_peaks_temp, 1)
# axis[1, 0].plot(B0_temp, m*B0_temp + b)
axis[1, 0].set_title("Peak 4")
axis[1, 0].set_yticks([])

axis[1, 1].plot(B0_temp, B0_fifth_peaks_temp, marker='o')
# m, b = np.polyfit(B0_temp, B0_fifth_peaks_temp, 1)
# axis[1, 1].plot(B0_temp, m*B0_temp + b)
axis[1, 1].set_title("Peak 5")
axis[1, 1].set_yticks([])


axis[1, 2].plot(B0_temp, B0_sixth_peaks_temp, marker='o')
# m, b = np.polyfit(B0_temp, B0_sixth_peaks_temp, 1)
# axis[1, 2].plot(B0_temp, m*B0_temp + b)
axis[1, 2].set_title("Peak 6")
axis[1, 2].set_yticks([])


axis[2, 0].plot(B0_temp, B0_seventh_peaks_temp, marker='o')
# m, b = np.polyfit(B0_temp, B0_seventh_peaks_temp, 1)
# axis[2, 0].plot(B0_temp, m*B0_temp + b)
axis[2, 0].set_title("Peak 7")
axis[2, 0].set_yticks([])


axis[2, 1].plot(B0_temp, B0_eight_peaks_temp, marker='o')
# m, b = np.polyfit(B0_temp, B0_eight_peaks_temp, 1)
# axis[2, 1].plot(B0_temp, m*B0_temp + b)
axis[2, 1].set_title("Peak 8")
axis[2, 1].set_yticks([])


axis[2, 2].plot(B0_temp, B0_ninth_peaks_temp, marker='o')
# m, b = np.polyfit(B0_temp, B0_ninth_peaks_temp, 1)
# axis[2, 2].plot(B0_temp, m*B0_temp + b)
axis[2, 2].set_title("Peak 9")
axis[2, 2].set_yticks([])


figure.tight_layout(pad=2.0)



figure.text(0.5, 0.002, 'Temperature (K)', ha='center', va='center')
figure.text(0.02, 0.5, 'Area (a.u.)', ha='center', va='center', rotation='vertical')
# Out:
# Text(0.02,0.5,'Area (a.u.)')

# %%
B0_first_peaks = []

B0_first_peaks.append(B0_94K_areas[0])
B0_first_peaks.append(B0_117K_areas[0])
B0_first_peaks.append(B0_137K_areas[0])
B0_first_peaks.append(B0_158K_areas[0])
B0_first_peaks.append(B0_180K_areas[0])
B0_first_peaks.append(B0_203K_areas[0])
B0_first_peaks.append(B0_227K_areas[0])
B0_first_peaks.append(B0_253K_areas[0])

B0_temp = [94,117,137,158,180,203,227,253]
plt.plot(B0_temp, B0_first_peaks, marker='o')
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under first peaks for B=0 and different temperatures")
plt.savefig('B0_first_peaks.png')

plt.plot(B3_temp, B3_first_peaks, color='red', marker='o')
#add legend to plot
plt.yticks([])
plt.legend(['B=0T', 'B=5T'])

# %%
B0_second_peaks = []

B0_second_peaks.append(B0_94K_areas[1])
B0_second_peaks.append(B0_117K_areas[1])
B0_second_peaks.append(B0_137K_areas[1])
B0_second_peaks.append(B0_158K_areas[1])
B0_second_peaks.append(B0_180K_areas[1])
B0_second_peaks.append(B0_203K_areas[1])
B0_second_peaks.append(B0_227K_areas[1])
B0_second_peaks.append(B0_253K_areas[1])

B0_temp = [94,117,137,158,180,203,227,253]
plt.plot(B0_temp, B0_second_peaks, marker='o')
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under second peaks for B=0T and B=5T")


plt.plot(B3_temp, B3_second_peaks, color='red', marker='o')
#add legend to plot
plt.legend(['B=0T', 'B=5T'])
plt.yticks([])
plt.savefig('B0_second_peaksSON.png')

# %%
B0_third_peaks = []

B0_third_peaks.append(B0_94K_areas[2])
B0_third_peaks.append(B0_117K_areas[2])
B0_third_peaks.append(B0_137K_areas[2])
B0_third_peaks.append(B0_158K_areas[2])
B0_third_peaks.append(B0_180K_areas[2])
B0_third_peaks.append(B0_203K_areas[2])
B0_third_peaks.append(B0_227K_areas[2])
B0_third_peaks.append(B0_253K_areas[2])

B0_temp = [94,117,137,158,180,203,227,253]
plt.plot(B0_temp, B0_third_peaks, marker='o')
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under third peaks for B=0 and B=5T")
plt.savefig('B0_third_peaks.png')

plt.plot(B3_temp, B3_third_peaks, color='red', marker = 'o')
#add legend to plot
plt.legend(['B=0T', 'B=5T'])
plt.yticks([])
plt.savefig('B3_third_peaks_report.png')

#Areas under third peaks for B=0 and B=5T

# %%
B0_fourth_peaks = []

B0_fourth_peaks.append(B0_94K_areas[3])
B0_fourth_peaks.append(B0_117K_areas[3])
B0_fourth_peaks.append(B0_137K_areas[3])
B0_fourth_peaks.append(B0_158K_areas[3])
B0_fourth_peaks.append(B0_180K_areas[3])
B0_fourth_peaks.append(B0_203K_areas[3])
B0_fourth_peaks.append(B0_227K_areas[3])
B0_fourth_peaks.append(B0_253K_areas[3])

B0_temp = [94,117,137,158,180,203,227,253]
plt.plot(B0_temp, B0_fourth_peaks, marker='o')
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under fourth peaks for B=0 and B=5T")
plt.savefig('B0_fourth_peaks.png')

plt.plot(B3_temp, B3_fourth_peaks, color='red', marker='o')
#add legend to plot
plt.legend(['B=0T', 'B=5T'])
plt.yticks([])
plt.savefig('B3_fourth_peaks_report.png')

# %%
B0_fifth_peaks = []

B0_fifth_peaks.append(B0_94K_areas[4])
B0_fifth_peaks.append(B0_117K_areas[4])
B0_fifth_peaks.append(B0_137K_areas[4])
B0_fifth_peaks.append(B0_158K_areas[4])
B0_fifth_peaks.append(B0_180K_areas[4])
B0_fifth_peaks.append(B0_203K_areas[4])
B0_fifth_peaks.append(B0_227K_areas[4])
B0_fifth_peaks.append(B0_253K_areas[4])

B0_temp = [94,117,137,158,180,203,227,253]
plt.plot(B0_temp, B0_fifth_peaks, marker='o')
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under fifth peaks for B=0 and different temperatures")
plt.savefig('B0_fifth_peaks.png')

plt.plot(B3_temp, B3_fifth_peaks, color='red', marker='o')
plt.yticks([])
#add legend to plot
plt.legend(['B=0T', 'B=5T'])

# %%
B0_sixth_peaks = []

B0_sixth_peaks.append(B0_94K_areas[5])
B0_sixth_peaks.append(B0_117K_areas[5])
B0_sixth_peaks.append(B0_137K_areas[5])
B0_sixth_peaks.append(B0_158K_areas[5])
B0_sixth_peaks.append(B0_180K_areas[5])
B0_sixth_peaks.append(B0_203K_areas[5])
B0_sixth_peaks.append(B0_227K_areas[5])
B0_sixth_peaks.append(B0_253K_areas[5])

B0_temp = [94,117,137,158,180,203,227,253]
plt.plot(B0_temp, B0_sixth_peaks, marker='o')
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under sixth peaks for B=0 and different temperatures")
plt.savefig('B0_sixth_peaks.png')

plt.plot(B3_temp, B3_sixth_peaks, color='red', marker='o')
plt.yticks([])
#add legend to plot
plt.legend(['B=0T', 'B=5T'])

# %%
B0_seventh_peaks = []

B0_seventh_peaks.append(B0_94K_areas[6])
B0_seventh_peaks.append(B0_117K_areas[6])
B0_seventh_peaks.append(B0_137K_areas[6])
B0_seventh_peaks.append(B0_158K_areas[6])
B0_seventh_peaks.append(B0_180K_areas[6])
B0_seventh_peaks.append(B0_203K_areas[6])
B0_seventh_peaks.append(B0_227K_areas[6])
B0_seventh_peaks.append(B0_253K_areas[6])

B0_temp = [94,117,137,158,180,203,227,253]
plt.plot(B0_temp, B0_seventh_peaks, marker='o')
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under seventh peaks for B=0 and different temperatures")
plt.savefig('B0_seventh_peaks.png')

# plt.plot(B3_temp, B3_seventh_peaks, color='red', marker='o')
# plt.yticks([])
# #add legend to plot
# plt.legend(['B=0T', 'B=5T'])
B0_180K_areas
# Out:
# [4579.0, 15883.0, 1092.0, 1717.0, 13041.5, 6941.0, 11582.0, 8478.5, 9860.5]

# %%
B0_eight_peaks = []

B0_eight_peaks.append(B0_94K_areas[7])
B0_eight_peaks.append(B0_117K_areas[7])
B0_eight_peaks.append(B0_137K_areas[7])
B0_eight_peaks.append(B0_158K_areas[7])
B0_eight_peaks.append(B0_180K_areas[7])
B0_eight_peaks.append(B0_203K_areas[7])
B0_eight_peaks.append(B0_227K_areas[7])
B0_eight_peaks.append(B0_253K_areas[7])

B0_temp = [94,117,137,158,180,203,227,253]
plt.plot(B0_temp, B0_eight_peaks, marker='o')
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under eight peaks for B=0 and different temperatures")
plt.savefig('B0_eight_peaks.png')

plt.plot(B3_temp, B3_eight_peaks, color='red', marker='o')
#add legend to plot
plt.yticks([])
plt.legend(['B=0T', 'B=5T'])

# %%
B0_ninth_peaks = []

B0_ninth_peaks.append(B0_94K_areas[8])
B0_ninth_peaks.append(B0_117K_areas[8])
B0_ninth_peaks.append(B0_137K_areas[8])
B0_ninth_peaks.append(B0_158K_areas[8])
B0_ninth_peaks.append(B0_180K_areas[8])
B0_ninth_peaks.append(B0_203K_areas[8])
B0_ninth_peaks.append(B0_227K_areas[8])
B0_ninth_peaks.append(B0_253K_areas[8])

B0_temp = [94,117,137,158,180,203,227,253]
plt.plot(B0_temp, B0_ninth_peaks, marker='o')
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under ninth peaks for B=0 and different temperatures")
plt.savefig('B0_ninth_peaks.png')

plt.plot(B3_temp, B3_ninth_peaks, color='red', marker='o')
#add legend to plot
plt.yticks([])
plt.legend(['B=0T', 'B=5T'])

# %%
import numpy as np

B3_first_peaks = []

B3_first_peaks.append(B3_76K_areas[0])
B3_first_peaks.append(B3_98K_areas[0])
B3_first_peaks.append(B3_118K_areas[0])
B3_first_peaks.append(B3_138K_areas[0])
B3_first_peaks.append(B3_157K_areas[0])
B3_first_peaks.append(B3_177K_areas[0])
B3_first_peaks.append(B3_197K_areas[0])
B3_first_peaks.append(B3_218K_areas[0])

B3_first_peaks = np.array(B3_first_peaks)

B3_temp = [76,98,118,138,157,177,197,218]
B3_temp = np.array(B3_temp)
plt.scatter(B3_temp, B3_first_peaks)
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under first peaks for B=5T and different temperatures")


m, b = np.polyfit(B3_temp, B3_first_peaks, 1)
plt.plot(B3_temp, m*B3_temp + b)
plt.savefig('B5_first_peaks_report.png')
plt.yticks([])
print(m)
# Out:
# -20.98752504972971

# %%
import numpy as np

B0_first_peaks = []

B0_first_peaks.append(B0_94K_areas[0])
B0_first_peaks.append(B0_117K_areas[0])
B0_first_peaks.append(B0_137K_areas[0])
B0_first_peaks.append(B0_158K_areas[0])
B0_first_peaks.append(B0_180K_areas[0])
B0_first_peaks.append(B0_203K_areas[0])
B0_first_peaks.append(B0_227K_areas[0])
B0_first_peaks.append(B0_253K_areas[0])

B0_first_peaks = np.array(B0_first_peaks)

B0_temp = [94,117,137,158,180,203,227,253]
B0_temp = np.array(B0_temp)
plt.scatter(B0_temp, B0_first_peaks)
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under first peaks for B=0T and different temperatures")


m, b = np.polyfit(B0_temp, B0_first_peaks, 1)
plt.plot(B0_temp, m*B0_temp + b)
plt.savefig('B0_first_peaks_report.png')
plt.yticks([])
print(m)
# Out:
# -0.5671165549831668

# %%
import numpy as np

B0_second_peaks = []

B0_second_peaks.append(B0_94K_areas[1])
B0_second_peaks.append(B0_117K_areas[1])
B0_second_peaks.append(B0_137K_areas[1])
B0_second_peaks.append(B0_158K_areas[1])
B0_second_peaks.append(B0_180K_areas[1])
B0_second_peaks.append(B0_203K_areas[1])
B0_second_peaks.append(B0_227K_areas[1])
B0_second_peaks.append(B0_253K_areas[1])

B0_second_peaks = np.array(B0_second_peaks)

B0_temp = [94,117,137,158,180,203,227,253]
B0_temp = np.array(B0_temp)
plt.scatter(B0_temp, B0_second_peaks)
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under second peaks for B=0T and different temperatures")


m, b = np.polyfit(B0_temp, B0_second_peaks, 1)
plt.plot(B0_temp, m*B0_temp + b)
plt.savefig('B0_second_peaks_report.png')
plt.yticks([])
print(m)
# Out:
# -15.275566451185545

# %%
import numpy as np

B0_third_peaks = []

B0_third_peaks.append(B0_94K_areas[2])
B0_third_peaks.append(B0_117K_areas[2])
B0_third_peaks.append(B0_137K_areas[2])
B0_third_peaks.append(B0_158K_areas[2])
B0_third_peaks.append(B0_180K_areas[2])
B0_third_peaks.append(B0_203K_areas[2])
B0_third_peaks.append(B0_227K_areas[2])
B0_third_peaks.append(B0_253K_areas[2])

B0_third_peaks = np.array(B0_third_peaks)

B0_temp = [94,117,137,158,180,203,227,253]
B0_temp = np.array(B0_temp)
plt.scatter(B0_temp, B0_third_peaks)
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under third peaks for B=0T and different temperatures")


m, b = np.polyfit(B0_temp, B0_third_peaks, 1)
plt.plot(B0_temp, m*B0_temp + b)
plt.savefig('B0_third_peaks_report.png')
plt.yticks([])
print(m)
# Out:
# -31.557387375132347

# %%
import numpy as np

B0_fourth_peaks = []

B0_fourth_peaks.append(B0_94K_areas[3])
B0_fourth_peaks.append(B0_117K_areas[3])
B0_fourth_peaks.append(B0_137K_areas[3])
B0_fourth_peaks.append(B0_158K_areas[3])
B0_fourth_peaks.append(B0_180K_areas[3])
B0_fourth_peaks.append(B0_203K_areas[3])
B0_fourth_peaks.append(B0_227K_areas[3])
B0_fourth_peaks.append(B0_253K_areas[3])

B0_fourth_peaks = np.array(B0_fourth_peaks)

B0_temp = [94,117,137,158,180,203,227,253]
B0_temp = np.array(B0_temp)
plt.scatter(B0_temp, B0_fourth_peaks)
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under fourth peaks for B=0T and different temperatures")


m, b = np.polyfit(B0_temp, B0_fourth_peaks, 1)
plt.plot(B0_temp, m*B0_temp + b)
plt.savefig('B0_fourth_peaks_report.png')
plt.yticks([])
print(m)
# Out:
# -18.833968145068283

# %%
import numpy as np

B0_fifth_peaks = []

B0_fifth_peaks.append(B0_94K_areas[4])
B0_fifth_peaks.append(B0_117K_areas[4])
B0_fifth_peaks.append(B0_137K_areas[4])
B0_fifth_peaks.append(B0_158K_areas[4])
B0_fifth_peaks.append(B0_180K_areas[4])
B0_fifth_peaks.append(B0_203K_areas[4])
B0_fifth_peaks.append(B0_227K_areas[4])
B0_fifth_peaks.append(B0_253K_areas[4])

B0_fifth_peaks = np.array(B0_fifth_peaks)

B0_temp = [94,117,137,158,180,203,227,253]
B0_temp = np.array(B0_temp)
plt.scatter(B0_temp, B0_fifth_peaks)
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under fifth peaks for B=0T and different temperatures")


m, b = np.polyfit(B0_temp, B0_fifth_peaks, 1)
plt.plot(B0_temp, m*B0_temp + b)
plt.savefig('B0_fifth_peaks_report.png')
plt.yticks([])
print(m)
# Out:
# 53.86878323150714

# %%
import numpy as np

B0_sixth_peaks = []

B0_sixth_peaks.append(B0_94K_areas[5])
B0_sixth_peaks.append(B0_117K_areas[5])
B0_sixth_peaks.append(B0_137K_areas[5])
B0_sixth_peaks.append(B0_158K_areas[5])
B0_sixth_peaks.append(B0_180K_areas[5])
B0_sixth_peaks.append(B0_203K_areas[5])
B0_sixth_peaks.append(B0_227K_areas[5])
B0_sixth_peaks.append(B0_253K_areas[5])

B0_sixth_peaks = np.array(B0_sixth_peaks)

B0_temp = [94,117,137,158,180,203,227,253]
B0_temp = np.array(B0_temp)
plt.scatter(B0_temp, B0_sixth_peaks)
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under sixth peaks for B=0T and different temperatures")


m, b = np.polyfit(B0_temp, B0_sixth_peaks, 1)
plt.plot(B0_temp, m*B0_temp + b)
plt.savefig('B0_sixth_peaks_report.png')
plt.yticks([])
print(m)
# Out:
# -6.99233790121778

# %%
import numpy as np

B0_seventh_peaks = []

B0_seventh_peaks.append(B0_94K_areas[6])
B0_seventh_peaks.append(B0_117K_areas[6])
B0_seventh_peaks.append(B0_137K_areas[6])
B0_seventh_peaks.append(B0_158K_areas[6])
B0_seventh_peaks.append(B0_180K_areas[6])
B0_seventh_peaks.append(B0_203K_areas[6])
B0_seventh_peaks.append(B0_227K_areas[6])
B0_seventh_peaks.append(B0_253K_areas[6])

B0_seventh_peaks = np.array(B0_seventh_peaks)

B0_temp = [94,117,137,158,180,203,227,253]
B0_temp = np.array(B0_temp)
plt.scatter(B0_temp, B0_seventh_peaks)
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under seventh peaks for B=0T and different temperatures")


m, b = np.polyfit(B0_temp, B0_seventh_peaks, 1)
plt.plot(B0_temp, m*B0_temp + b)
plt.savefig('B0_seventh_peaks_report.png')
plt.yticks([])
print(m)
# Out:
# 62.20612553894925

# %%
import numpy as np

B0_eight_peaks = []

B0_eight_peaks.append(B0_94K_areas[7])
B0_eight_peaks.append(B0_117K_areas[7])
B0_eight_peaks.append(B0_137K_areas[7])
B0_eight_peaks.append(B0_158K_areas[7])
B0_eight_peaks.append(B0_180K_areas[7])
B0_eight_peaks.append(B0_203K_areas[7])
B0_eight_peaks.append(B0_227K_areas[7])
B0_eight_peaks.append(B0_253K_areas[7])

B0_eight_peaks = np.array(B0_eight_peaks)

B0_temp = [94,117,137,158,180,203,227,253]
B0_temp = np.array(B0_temp)
plt.scatter(B0_temp, B0_eight_peaks)
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under eight peaks for B=0T and different temperatures")


m, b = np.polyfit(B0_temp, B0_eight_peaks, 1)
plt.plot(B0_temp, m*B0_temp + b)
plt.savefig('B0_eight_peaks_report.png')
plt.yticks([])
print(m)
# Out:
# 19.888889217466396

# %%
import numpy as np

B0_ninth_peaks = []

B0_ninth_peaks.append(B0_94K_areas[8])
B0_ninth_peaks.append(B0_117K_areas[8])
B0_ninth_peaks.append(B0_137K_areas[8])
B0_ninth_peaks.append(B0_158K_areas[8])
B0_ninth_peaks.append(B0_180K_areas[8])
B0_ninth_peaks.append(B0_203K_areas[8])
B0_ninth_peaks.append(B0_227K_areas[8])
B0_ninth_peaks.append(B0_253K_areas[8])

B0_ninth_peaks = np.array(B0_ninth_peaks)

B0_temp = [94,117,137,158,180,203,227,253]
B0_temp = np.array(B0_temp)
plt.scatter(B0_temp, B0_ninth_peaks)
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under ninth peaks for B=0T and different temperatures")


m, b = np.polyfit(B0_temp, B0_ninth_peaks, 1)
plt.plot(B0_temp, m*B0_temp + b)
plt.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
B3_second_peaks = []

B3_second_peaks.append(B3_76K_areas[1])
B3_second_peaks.append(B3_98K_areas[1])
B3_second_peaks.append(B3_118K_areas[1])
B3_second_peaks.append(B3_138K_areas[1])
B3_second_peaks.append(B3_157K_areas[1])
B3_second_peaks.append(B3_177K_areas[1])
B3_second_peaks.append(B3_197K_areas[1])
B3_second_peaks.append(B3_218K_areas[1])

B3_second_peaks = np.array(B3_second_peaks)


B3_temp = [76,98,118,138,157,177,197,218]

B3_temp= np.array(B3_temp)

plt.scatter(B3_temp, B3_second_peaks)
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under second peaks for B=5T and different temperatures")
plt.savefig('B5_second_peaks.png')

m, b = np.polyfit(B3_temp, B3_second_peaks, 1)
plt.plot(B3_temp, m*B3_temp + b)
plt.yticks([])
print(m)
# Out:
# -60.53863019573912

# %%
B3_third_peaks = []

B3_third_peaks.append(B3_76K_areas[2])
B3_third_peaks.append(B3_98K_areas[2])
B3_third_peaks.append(B3_118K_areas[2])
B3_third_peaks.append(B3_138K_areas[2])
B3_third_peaks.append(B3_157K_areas[2])
B3_third_peaks.append(B3_177K_areas[2])
B3_third_peaks.append(B3_197K_areas[2])
B3_third_peaks.append(B3_218K_areas[2])

B3_third_peaks = np.array(B3_third_peaks)

B3_temp = [76,98,118,138,157,177,197,218]
B3_temp= np.array(B3_temp)
plt.scatter(B3_temp, B3_third_peaks)
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under third peaks for B=5T and different temperatures")
plt.savefig('B5_third_peaks.png')

m, b = np.polyfit(B3_temp, B3_third_peaks, 1)
plt.plot(B3_temp, m*B3_temp + b)
plt.yticks([])
print(m)
# Out:
# -22.631844769320654

# %%
B3_fourth_peaks = []

B3_fourth_peaks.append(B3_76K_areas[3])
B3_fourth_peaks.append(B3_98K_areas[3])
B3_fourth_peaks.append(B3_118K_areas[3])
B3_fourth_peaks.append(B3_138K_areas[3])
B3_fourth_peaks.append(B3_157K_areas[3])
B3_fourth_peaks.append(B3_177K_areas[3])
B3_fourth_peaks.append(B3_197K_areas[3])
B3_fourth_peaks.append(B3_218K_areas[3])

B3_fourth_peaks = np.array(B3_fourth_peaks)


B3_temp = [76,98,118,138,157,177,197,218]
B3_temp= np.array(B3_temp)
plt.scatter(B3_temp, B3_fourth_peaks)
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under fourth peaks for B=5T and different temperatures")
plt.savefig('B5_fourth_peaks.png')

m, b = np.polyfit(B3_temp, B3_fourth_peaks, 1)
plt.plot(B3_temp, m*B3_temp + b)
plt.yticks([])

print(m)
# Out:
# -10.913758679592695

# %%
B3_fifth_peaks = []

B3_fifth_peaks.append(B3_76K_areas[4])
B3_fifth_peaks.append(B3_98K_areas[4])
B3_fifth_peaks.append(B3_118K_areas[4])
B3_fifth_peaks.append(B3_138K_areas[4])
B3_fifth_peaks.append(B3_157K_areas[4])
B3_fifth_peaks.append(B3_177K_areas[4])
B3_fifth_peaks.append(B3_197K_areas[4])
B3_fifth_peaks.append(B3_218K_areas[4])

B3_fifth_peaks= np.array(B3_fifth_peaks)

B3_temp = [76,98,118,138,157,177,197,218]
B3_temp= np.array(B3_temp)
plt.scatter(B3_temp, B3_fifth_peaks)
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under fifth peaks for B=5T and different temperatures")
plt.savefig('B5_fifth_peaks.png')

m, b = np.polyfit(B3_temp, B3_fifth_peaks, 1)
plt.plot(B3_temp, m*B3_temp + b)
plt.yticks([])
print(m)
# Out:
# -41.894029475490086

# %%
B3_sixth_peaks = []

B3_sixth_peaks.append(B3_76K_areas[5])
B3_sixth_peaks.append(B3_98K_areas[5])
B3_sixth_peaks.append(B3_118K_areas[5])
B3_sixth_peaks.append(B3_138K_areas[5])
B3_sixth_peaks.append(B3_157K_areas[5])
B3_sixth_peaks.append(B3_177K_areas[5])
B3_sixth_peaks.append(B3_197K_areas[5])
B3_sixth_peaks.append(B3_218K_areas[5])

B3_sixth_peaks = np.array(B3_sixth_peaks)

B3_temp = [76,98,118,138,157,177,197,218]
B3_temp= np.array(B3_temp)
plt.scatter(B3_temp, B3_sixth_peaks)
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under sixth peaks for B=5T and different temperatures")


m, b = np.polyfit(B3_temp, B3_sixth_peaks, 1)
plt.plot(B3_temp, m*B3_temp + b)
plt.savefig('B5_sixth_peaks.png')
plt.yticks([])
print(m)
# Out:
# 43.471145669262214

# %%
B3_seventh_peaks = []

B3_seventh_peaks.append(B3_76K_areas[6])
B3_seventh_peaks.append(B3_98K_areas[6])
B3_seventh_peaks.append(B3_118K_areas[6])
B3_seventh_peaks.append(B3_138K_areas[6])
B3_seventh_peaks.append(B3_157K_areas[6])
B3_seventh_peaks.append(B3_177K_areas[6])
B3_seventh_peaks.append(B3_197K_areas[6])
B3_seventh_peaks.append(B3_218K_areas[6])

B3_seventh_peaks = np.array(B3_seventh_peaks)

B3_temp = [76,98,118,138,157,177,197,218]
B3_temp= np.array(B3_temp)
plt.scatter(B3_temp, B3_seventh_peaks)
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under seventh peaks for B=5T and different temperatures")
plt.savefig('B5_seventh_peaks.png')

m, b = np.polyfit(B3_temp, B3_seventh_peaks, 1)
plt.plot(B3_temp, m*B3_temp + b)
plt.yticks([])
print(m)
# Out:
# -8.841818813733543

# %%
B3_eight_peaks = []

B3_eight_peaks.append(B3_76K_areas[7])
B3_eight_peaks.append(B3_98K_areas[7])
B3_eight_peaks.append(B3_118K_areas[7])
B3_eight_peaks.append(B3_138K_areas[7])
B3_eight_peaks.append(B3_157K_areas[7])
B3_eight_peaks.append(B3_177K_areas[7])
B3_eight_peaks.append(B3_197K_areas[7])
B3_eight_peaks.append(B3_218K_areas[7])

B3_eight_peaks= np.array(B3_eight_peaks)

B3_temp = [76,98,118,138,157,177,197,218]
B3_temp= np.array(B3_temp)
plt.scatter(B3_temp, B3_eight_peaks)
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under eight peaks for B=5T and different temperatures")
plt.savefig('B5_eight_peaks.png')

m, b = np.polyfit(B3_temp, B3_eight_peaks, 1)
plt.plot(B3_temp, m*B3_temp + b)
plt.yticks([])
print(m)
# Out:
# -19.88857954167315

# %%
B3_first_peaks = []

B3_first_peaks.append(B3_76K_areas[0])
B3_first_peaks.append(B3_98K_areas[0])
B3_first_peaks.append(B3_118K_areas[0])
B3_first_peaks.append(B3_138K_areas[0])
B3_first_peaks.append(B3_157K_areas[0])
B3_first_peaks.append(B3_177K_areas[0])
B3_first_peaks.append(B3_197K_areas[0])
B3_first_peaks.append(B3_218K_areas[0])

B3_first_peaks= np.array(B3_first_peaks)

B3_temp = [76,98,118,138,157,177,197,218]
B3_temp= np.array(B3_temp)
plt.scatter(B3_temp, B3_first_peaks)
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under first peaks for B=5T and different temperatures")
plt.savefig('B5_first_peaks.png')

m, b = np.polyfit(B3_temp, B3_first_peaks, 1)
plt.plot(B3_temp, m*B3_temp + b)
plt.yticks([])
print(m)
# Out:
# -20.98752504972971

# %%
B3_ninth_peaks = []

B3_ninth_peaks.append(B3_76K_areas[8])
B3_ninth_peaks.append(B3_98K_areas[8])
B3_ninth_peaks.append(B3_118K_areas[8])
B3_ninth_peaks.append(B3_138K_areas[8])
B3_ninth_peaks.append(B3_157K_areas[8])
B3_ninth_peaks.append(B3_177K_areas[8])
B3_ninth_peaks.append(B3_197K_areas[8])
B3_ninth_peaks.append(B3_218K_areas[8])

B3_ninth_peaks = np.array(B3_ninth_peaks)

B3_temp = [76,98,118,138,157,177,197,218]
B3_temp= np.array(B3_temp)
plt.scatter(B3_temp, B3_ninth_peaks)
plt.xlabel('Temperature (K)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under ninth peaks for B=5T and different temperatures")
plt.savefig('B5_ninth_peaks.png')







plt.yticks([])
m, b = np.polyfit(B3_temp, B3_ninth_peaks, 1)
plt.plot(B3_temp, m*B3_temp + b)
print(m)
# Out:
# -7.899142947992711

# %%
import seaborn as sns

df_B0_areas = pd.DataFrame({"Temperature": B0_temp, "Area_1": B0_first_peaks, "Area_2": B0_second_peaks, "Area_3": B0_third_peaks, "Area_4": B0_fourth_peaks, "Area_5": B0_fifth_peaks, "Area_6": B0_sixth_peaks, "Area_7": B0_seventh_peaks, "Area_8": B0_eight_peaks, "Area_9": B0_ninth_peaks})
df_B3_areas = pd.DataFrame({"Temperature": B3_temp, "Area_1": B3_first_peaks, "Area_2": B3_second_peaks, "Area_3": B3_third_peaks, "Area_4": B3_fourth_peaks, "Area_5": B3_fifth_peaks, "Area_6": B3_sixth_peaks, "Area_7": B3_seventh_peaks, "Area_8": B3_eight_peaks, "Area_9": B3_ninth_peaks})

# %%
df_B0_areas
# Out:
#              Area_1   Area_2  Area_3  Area_4   Area_5  Area_6   Area_7  \
# Temperature
# 94           4662.5  10363.5  5221.0  2826.5   6704.5  7149.5   3813.0
# 117          4547.0   8153.0  4509.5  4416.0   6969.5  7318.0   2743.5
# 137          4463.0  15052.5  4178.5  1724.0   5094.5  6675.0   7450.0
# 158          4406.5   2111.5  2222.0  2442.5   2077.0  6813.5   3216.0
# 180          4579.0  15883.0  1092.0  1717.0  13041.5  6941.0  11582.0
# 203          5063.5  15542.5    97.0   483.0  13266.5  6431.5  11704.0
# 227          4483.0  13374.0   997.5   867.5  12761.0  6246.0  12767.0
# 253          4291.0    921.5  1014.0   864.0  11997.5  6123.0  10559.0
#
#               Area_8   Area_9
# Temperature
# 94            7119.0   6038.5
# 117           7426.0   5344.5
# 137           6135.0   4352.0
# 158           6389.0   6453.0
# 180           8478.5   9860.5
# 203           8807.5  10609.5
# 227           8468.0   8730.0
# 253          10203.5  10020.0

# %%
plt.figure(figsize=(15,10))
plt.title("Heatmap for areas under different temperatures for B=0T")
ax = sns.heatmap(df_B0_areas, cmap="YlGnBu", annot=True, fmt=".2f")
ax.set_ylim([0,8])
plt.savefig('B0_heatmap_report.png')

#Heatmap for areas under different temperatures for B=0T

# %%
corr=df_B0_areas.corr()
corr.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_9c12ec95_f2da_11ec_b434_b42e99d0614erow0_col0,#T_9c12ec95_f2da_11ec_b434_b42e99d0614erow1_col1,#T_9c12ec95_f2da_11ec_b434_b42e99d0614erow2_col2,#T_9c12ec95_f2da_11ec_b434_b42e99d0614erow3_col3,#T_9c12ec95_f2da_11ec_b434_b42e99d0614erow4_col4,#T_9c12ec95_f2da_11ec_b434_b42e99d0614erow5_col5,#T_9c12ec95_f2da_11ec_b434_b42e99d0614erow6_col6,#T_9c12ec95_f2da_11ec_b434_b42e99d0614erow7_col7,#T_9c12ec95_f2da_11ec_b434_b42e99d0614erow8_col8{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_9c12ec95_f2da_11ec_b434_b42e99d0614erow0_col1{
#             background-color:  #2182b9;
#             color:  #000000;
#         }#T_9c12ec95_f2da_11ec_b434_b42e99d0614erow0_col2{
#             background-color:  #a5bddb;
#             color:  #000000;
#         }#T_9c12ec95_f2da_11ec_b434_b42e99d0614erow0_col3{
#             background-color:  #a7bddb;
#             color:  #000000;
# ...

# %%
B0_sum_areas = (sum(B0_94K_areas)+sum(B0_117K_areas)+sum(B0_137K_areas)+sum(B0_158K_areas)+sum(B0_180K_areas)+sum(B0_203K_areas)+sum(B0_227K_areas)+sum(B0_253K_areas))

B3_sum_areas = (sum(B3_76K_areas)+sum(B3_98K_areas)+sum(B3_118K_areas)+sum(B3_138K_areas)+sum(B3_157K_areas)+sum(B3_177K_areas)+sum(B3_197K_areas)+sum(B3_218K_areas))

sums = [B0_sum_areas, B3_sum_areas]

sums_temp = ["0K", "5K"]
plt.bar(sums_temp, sums)
plt.xlabel('Magnetic Field (T)')
# Set the y axis label of the current axis.
plt.ylabel('Area (a.u.)')
plt.title("Areas under all peaks for different magnetic fields")
# Out:
# Text(0.5,1,'Areas under all peaks for different magnetic fields')
